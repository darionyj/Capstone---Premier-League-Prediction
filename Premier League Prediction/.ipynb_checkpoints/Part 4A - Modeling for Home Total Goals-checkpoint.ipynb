# %% [markdown]
# # Capstone Project: English Premier League Predictions

# %% [markdown]
# # Part 4A - Preprocessing, Modeling & Evaluation for Home Total Goals
#
# In this notebook, we will be training the model for our target variable, Home Total Goals.  Similarly to Result, we will be using the dataset which we have combined in the notebook Part 2.
#
# The models used to train will be as followed in the contents. We will grid search for the best parameters for each models then use it with the models.
#
# ### Contents:
#
# - [Preparing Dataset for Prediction of Home Total Goals](#Preparing-Dataset-for-Prediction-of-Home-Total-Goals)
#     - [Home Total Goals Classes](#Home-Total-Goals-Classes)
#     - [Removing Features that will be Irrelevant](#Removing-Features-that-will-be-Irrelevant)
#
# - [Building the Model](#Building-the-Modeling)
#     - [Train Test Split for Home Total Goals](#Train-Test-Split-for-Home-Total-Goals)
#     - [Logistic Regression](#Logistic-Regression)
#     - [Random Forest Classification](#Random-Forest-Classification)
#     - [ExtraTrees Classifier](#ExtraTrees-Classifier)
#     - [AdaBoost Classifier](#AdaBoost-Classifier)
#     - [Gradient Boost Classifier](#Gradient-Boost-Classifier)
#     - [Support Vector Classifier](#Support-Vector-Classifier)
#     - [Model Evaluation & Selection](#Model-Evaluation-&-Selection)

# %% [markdown]
# ## Importing Modules & Dataset

# %%
#Importing of modules
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import itertools
import functools
import pickle

from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier,plot_tree, export_graphviz
from sklearn.svm import SVC
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import precision_score,confusion_matrix,accuracy_score,recall_score,f1_score,precision_recall_fscore_support,plot_confusion_matrix

from imblearn.over_sampling import SMOTE

import warnings
import graphviz
warnings.filterwarnings("ignore")

pd.set_option('max_columns',None)

# %%
#Reading in of database
train = pd.read_csv('data/clean/combined_final.csv')

# %% [markdown]
# ## Preparing Dataset for Prediction of Home Total Goals
#
# Firstly, we will prepare the final dataset for prediction of total goals for Home. We will look through null values and remove features such as current matches stats as they will only happen after a match happened.

# %%
#We still have 280 features, we will look into remove some
train.shape
# Out:
# (1324, 264)

# %%
#Looking for null values
train.isnull().sum()[train.isnull().sum()>0]
# Out:
# h_last_5_avrg_gls         12
# h_last_5_avrg_ast         12
# h_last_5_avrg_pk          12
# h_last_5_avrg_pkatt       12
# h_last_5_avrg_sh          12
#                           ..
# a_last_3_avrg_pkcon       15
# a_last_3_avrg_og          15
# a_last_3_avrg_recov       15
# a_last_3_avrg_aer_won     15
# a_last_3_avrg_aer_lost    15
# Length: 144, dtype: int64

# %%
train.head(5)
# Out:
#          date                                      match  \
# 0  2017-08-11                  Arsenal_vs_Leicester_City
# 1  2017-08-12        Crystal_Palace_vs_Huddersfield_Town
# 2  2017-08-12                         Chelsea_vs_Burnley
# 3  2017-08-12  Brighton_&_Hove_Albion_vs_Manchester_City
# 4  2017-08-12        West_Bromwich_Albion_vs_Bournemouth
#
#                      home                                            stadium  \
# 0                 Arsenal                           Emirates Stadium, London
# 1          Crystal Palace                              Selhurst Park, London
# 2                 Chelsea                            Stamford Bridge, London
# 3  Brighton & Hove Albion  The American Express Community Stadium, Bright...
# 4    West Bromwich Albion                       The Hawthorns, West Bromwich
#
#    attendance  h_gls  h_ast  h_pk  h_pkatt  h_sh  h_sot  h_yellow  h_red  \
# 0       59387      4      4     0        0    28     10         0      0
# 1       25448      0      0     0        0    13      3         1      0
# 2       41616      2      2     0        0    18      6         4      2
# 3       30415      0      0     0        0     7      2         0      0
# 4       25011      1      1     0        0    17      6         3      0
#
#    h_touches  h_press  h_tkl  h_int  h_blk  h_xg  h_npxg  h_xa  h_sca  h_gca  \
# 0      782.0    162.0   20.0      9   11.0   2.2     2.2   2.2   51.0    7.0
# 1      563.0     98.0   18.0      9   17.0   0.9     0.9   0.3   12.0    0.0
# 2      647.0    114.0    8.0      2   11.0   1.0     1.0   0.8   28.0    4.0
# 3      338.0    217.0    7.0      9   22.0   0.5     0.5   0.2    9.0    0.0
# 4      399.0    136.0   15.0      9   17.0   1.1     1.1   0.9   25.0    2.0
#
#    h_cmp  h_pass_att  h_pass_prog  h_carries  h_carries_prog  h_dri_succ  \
# 0  546.0       659.0         50.0      593.0            90.0        15.0
# 1  326.0       445.0         39.0      350.0            33.0        13.0
# 2  455.0       561.0         37.0      424.0            72.0         9.0
# 3  138.0       241.0         10.0      150.0            10.0         7.0
# 4  188.0       294.0         14.0      218.0            21.0         3.0
#
#    h_dri_att  h_yellow2  h_fls  h_fld  h_off  h_crs  h_tklw  h_pkwon  h_pkcon  \
# 0       20.0          0      9     13      5     15      13      0.0      0.0
# 1       23.0          0      8     20      0     10       9      0.0      0.0
# 2       12.0          1     15     14      3     18       6      0.0      0.0
# 3       11.0          0      8      7      6      4       5      0.0      0.0
# 4        9.0          0     21      2      2     13      12      0.0      0.0
#
#    h_og  h_recov  h_aer_won  h_aer_lost  h_last_5_avrg_gls  h_last_5_avrg_ast  \
# 0     0    113.0       11.0         7.0                NaN                NaN
# 1     1    116.0       13.0         7.0                NaN                NaN
# 2     0    110.0        8.0        14.0                NaN                NaN
# 3     1     78.0        6.0         5.0                NaN                NaN
# 4     0     94.0        9.0        10.0                NaN                NaN
#
#    h_last_5_avrg_pk  h_last_5_avrg_pkatt  h_last_5_avrg_sh  h_last_5_avrg_sot  \
# 0               NaN                  NaN               NaN                NaN
# 1               NaN                  NaN               NaN                NaN
# 2               NaN                  NaN               NaN                NaN
# 3               NaN                  NaN               NaN                NaN
# 4               NaN                  NaN               NaN                NaN
#
#    h_last_5_avrg_yellow  h_last_5_avrg_red  h_last_5_touches  \
# 0                   NaN                NaN               NaN
# 1                   NaN                NaN               NaN
# 2                   NaN                NaN               NaN
# 3                   NaN                NaN               NaN
# 4                   NaN                NaN               NaN
#
#    h_last_5_avrg_press  h_last_5_avrg_tkl  h_last_5_avrg_int  \
# 0                  NaN                NaN                NaN
# 1                  NaN                NaN                NaN
# 2                  NaN                NaN                NaN
# 3                  NaN                NaN                NaN
# 4                  NaN                NaN                NaN
#
#    h_last_5_avrg_blk  h_last_5_avrg_xg  h_last_5_avrg_xa  h_last_5_avrg_sca  \
# 0                NaN               NaN               NaN                NaN
# 1                NaN               NaN               NaN                NaN
# 2                NaN               NaN               NaN                NaN
# 3                NaN               NaN               NaN                NaN
# 4                NaN               NaN               NaN                NaN
#
#    h_last_5_avrg_gca  h_last_5_avrg_cmp  h_last_5_avrg_pass_att  \
# 0                NaN                NaN                     NaN
# 1                NaN                NaN                     NaN
# 2                NaN                NaN                     NaN
# 3                NaN                NaN                     NaN
# 4                NaN                NaN                     NaN
#
#    h_last_5_avrg_pass_prog  h_last_5_avrg_carries  h_last_5_avrg_carries_prog  \
# 0                      NaN                    NaN                         NaN
# 1                      NaN                    NaN                         NaN
# 2                      NaN                    NaN                         NaN
# 3                      NaN                    NaN                         NaN
# 4                      NaN                    NaN                         NaN
#
#    h_last_5_avrg_dri_succ  h_last_5_avrg_dri_att  h_last_5_avrg_yellow2  \
# 0                     NaN                    NaN                    NaN
# 1                     NaN                    NaN                    NaN
# 2                     NaN                    NaN                    NaN
# 3                     NaN                    NaN                    NaN
# 4                     NaN                    NaN                    NaN
#
#    h_last_5_avrg_fls  h_last_5_avrg_fld  h_last_5_avrg_off  h_last_5_avrg_crs  \
# 0                NaN                NaN                NaN                NaN
# 1                NaN                NaN                NaN                NaN
# 2                NaN                NaN                NaN                NaN
# 3                NaN                NaN                NaN                NaN
# 4                NaN                NaN                NaN                NaN
#
#    h_last_5_avrg_tklw  h_last_5_avrg_pkwon  h_last_5_avrg_pkcon  \
# 0                 NaN                  NaN                  NaN
# 1                 NaN                  NaN                  NaN
# 2                 NaN                  NaN                  NaN
# 3                 NaN                  NaN                  NaN
# 4                 NaN                  NaN                  NaN
#
#    h_last_5_avrg_og  h_last_5_avrg_recov  h_last_5_avrg_aer_won  \
# 0               NaN                  NaN                    NaN
# 1               NaN                  NaN                    NaN
# 2               NaN                  NaN                    NaN
# 3               NaN                  NaN                    NaN
# 4               NaN                  NaN                    NaN
#
#    h_last_5_avrg_aer_lost  h_last_3_avrg_gls  h_last_3_avrg_ast  \
# 0                     NaN                NaN                NaN
# 1                     NaN                NaN                NaN
# 2                     NaN                NaN                NaN
# 3                     NaN                NaN                NaN
# 4                     NaN                NaN                NaN
#
#    h_last_3_avrg_pk  h_last_3_avrg_pkatt  h_last_3_avrg_sh  h_last_3_avrg_sot  \
# 0               NaN                  NaN               NaN                NaN
# 1               NaN                  NaN               NaN                NaN
# 2               NaN                  NaN               NaN                NaN
# 3               NaN                  NaN               NaN                NaN
# 4               NaN                  NaN               NaN                NaN
#
#    h_last_3_avrg_yellow  h_last_3_avrg_red  h_last_3_touches  \
# 0                   NaN                NaN               NaN
# 1                   NaN                NaN               NaN
# 2                   NaN                NaN               NaN
# 3                   NaN                NaN               NaN
# 4                   NaN                NaN               NaN
#
#    h_last_3_avrg_press  h_last_3_avrg_tkl  h_last_3_avrg_int  \
# 0                  NaN                NaN                NaN
# 1                  NaN                NaN                NaN
# 2                  NaN                NaN                NaN
# 3                  NaN                NaN                NaN
# 4                  NaN                NaN                NaN
#
#    h_last_3_avrg_blk  h_last_3_avrg_xg  h_last_3_avrg_xa  h_last_3_avrg_sca  \
# 0                NaN               NaN               NaN                NaN
# 1                NaN               NaN               NaN                NaN
# 2                NaN               NaN               NaN                NaN
# 3                NaN               NaN               NaN                NaN
# 4                NaN               NaN               NaN                NaN
#
#    h_last_3_avrg_gca  h_last_3_avrg_cmp  h_last_3_avrg_pass_att  \
# 0                NaN                NaN                     NaN
# 1                NaN                NaN                     NaN
# 2                NaN                NaN                     NaN
# 3                NaN                NaN                     NaN
# 4                NaN                NaN                     NaN
#
#    h_last_3_avrg_pass_prog  h_last_3_avrg_carries  h_last_3_avrg_carries_prog  \
# 0                      NaN                    NaN                         NaN
# 1                      NaN                    NaN                         NaN
# 2                      NaN                    NaN                         NaN
# 3                      NaN                    NaN                         NaN
# 4                      NaN                    NaN                         NaN
#
#    h_last_3_avrg_dri_succ  h_last_3_avrg_dri_att  h_last_3_avrg_yellow2  \
# 0                     NaN                    NaN                    NaN
# 1                     NaN                    NaN                    NaN
# 2                     NaN                    NaN                    NaN
# 3                     NaN                    NaN                    NaN
# 4                     NaN                    NaN                    NaN
#
#    h_last_3_avrg_fls  h_last_3_avrg_fld  h_last_3_avrg_off  h_last_3_avrg_crs  \
# 0                NaN                NaN                NaN                NaN
# 1                NaN                NaN                NaN                NaN
# 2                NaN                NaN                NaN                NaN
# 3                NaN                NaN                NaN                NaN
# 4                NaN                NaN                NaN                NaN
#
#    h_last_3_avrg_tklw  h_last_3_avrg_pkwon  h_last_3_avrg_pkcon  \
# 0                 NaN                  NaN                  NaN
# 1                 NaN                  NaN                  NaN
# 2                 NaN                  NaN                  NaN
# 3                 NaN                  NaN                  NaN
# 4                 NaN                  NaN                  NaN
#
#    h_last_3_avrg_og  h_last_3_avrg_recov  h_last_3_avrg_aer_won  \
# 0               NaN                  NaN                    NaN
# 1               NaN                  NaN                    NaN
# 2               NaN                  NaN                    NaN
# 3               NaN                  NaN                    NaN
# 4               NaN                  NaN                    NaN
#
#    h_last_3_avrg_aer_lost               away  a_gls  a_ast  a_pk  a_pkatt  \
# 0                     NaN     Leicester City      3      3     0        0
# 1                     NaN  Huddersfield Town      2      2     0        0
# 2                     NaN            Burnley      3      3     0        0
# 3                     NaN    Manchester City      1      1     0        0
# 4                     NaN        Bournemouth      0      0     0        0
#
#    a_sh  a_sot  a_yellow  a_red  a_touches  a_press  a_tkl  a_int  a_blk  \
# 0     6      4         1      0      419.0    137.0   10.0      5   25.0
# 1    10      6         3      0      461.0    122.0   26.0      3   19.0
# 2    10      5         3      0      447.0    116.0    7.0     10   20.0
# 3    14      4         2      0      888.0    156.0   10.0     10   15.0
# 4     9      2         1      0      739.0    114.0   20.0      0   13.0
#
#    a_xg  a_npxg  a_xa  a_sca  a_gca  a_cmp  a_pass_att  a_pass_prog  \
# 0   1.6     1.6   1.5    6.0    5.0  179.0       305.0         16.0
# 1   1.6     1.6   1.4   11.0    4.0  224.0       343.0         15.0
# 2   0.8     0.8   0.6   16.0    6.0  248.0       344.0         23.0
# 3   1.7     1.7   0.8   22.0    2.0  693.0       786.0         60.0
# 4   0.4     0.4   0.3   14.0    0.0  530.0       642.0         41.0
#
#    a_carries  a_carries_prog  a_dri_succ  a_dri_att  a_yellow2  a_fls  a_fld  \
# 0      184.0            24.0         1.0       11.0          0     13      9
# 1      228.0            20.0         2.0        7.0          0     20      8
# 2      235.0            23.0         3.0        4.0          0     14     16
# 3      632.0            88.0         6.0       13.0          0      8      7
# 4      589.0            55.0        13.0       21.0          0      3     21
#
#    a_off  a_crs  a_tklw  a_pwon  a_pkcon  a_og  a_recov  a_aer_won  \
# 0      3     20       6     0.0      0.0     0    104.0        7.0
# 1      2      6      14     0.0      0.0     0     99.0        7.0
# 2      1      7       4     0.0      0.0     0     88.0       14.0
# 3      1     16       6     0.0      0.0     0     79.0        5.0
# 4      0     21      11     0.0      0.0     0    110.0       10.0
#
#    a_aer_lost  a_last_5_avrg_gls  a_last_5_avrg_ast  a_last_5_avrg_pk  \
# 0        11.0                NaN                NaN               NaN
# 1        13.0                NaN                NaN               NaN
# 2         8.0                NaN                NaN               NaN
# 3         6.0                NaN                NaN               NaN
# 4         9.0                NaN                NaN               NaN
#
#    a_last_5_avrg_pkatt  a_last_5_avrg_sh  a_last_5_avrg_sot  \
# 0                  NaN               NaN                NaN
# 1                  NaN               NaN                NaN
# 2                  NaN               NaN                NaN
# 3                  NaN               NaN                NaN
# 4                  NaN               NaN                NaN
#
#    a_last_5_avrg_yellow  a_last_5_avrg_red  a_last_5_touches  \
# 0                   NaN                NaN               NaN
# 1                   NaN                NaN               NaN
# 2                   NaN                NaN               NaN
# 3                   NaN                NaN               NaN
# 4                   NaN                NaN               NaN
#
#    a_last_5_avrg_press  a_last_5_avrg_tkl  a_last_5_avrg_int  \
# 0                  NaN                NaN                NaN
# 1                  NaN                NaN                NaN
# 2                  NaN                NaN                NaN
# 3                  NaN                NaN                NaN
# 4                  NaN                NaN                NaN
#
#    a_last_5_avrg_blk  a_last_5_avrg_xg  a_last_5_avrg_xa  a_last_5_avrg_sca  \
# 0                NaN               NaN               NaN                NaN
# 1                NaN               NaN               NaN                NaN
# 2                NaN               NaN               NaN                NaN
# 3                NaN               NaN               NaN                NaN
# 4                NaN               NaN               NaN                NaN
#
#    a_last_5_avrg_gca  a_last_5_avrg_cmp  a_last_5_avrg_pass_att  \
# 0                NaN                NaN                     NaN
# 1                NaN                NaN                     NaN
# 2                NaN                NaN                     NaN
# 3                NaN                NaN                     NaN
# 4                NaN                NaN                     NaN
#
#    a_last_5_avrg_pass_prog  a_last_5_avrg_carries  a_last_5_avrg_carries_prog  \
# 0                      NaN                    NaN                         NaN
# 1                      NaN                    NaN                         NaN
# 2                      NaN                    NaN                         NaN
# 3                      NaN                    NaN                         NaN
# 4                      NaN                    NaN                         NaN
#
#    a_last_5_avrg_dri_succ  a_last_5_avrg_dri_att  a_last_5_avrg_yellow2  \
# 0                     NaN                    NaN                    NaN
# 1                     NaN                    NaN                    NaN
# 2                     NaN                    NaN                    NaN
# 3                     NaN                    NaN                    NaN
# 4                     NaN                    NaN                    NaN
#
#    a_last_5_avrg_fls  a_last_5_avrg_fld  a_last_5_avrg_off  a_last_5_avrg_crs  \
# 0                NaN                NaN                NaN                NaN
# 1                NaN                NaN                NaN                NaN
# 2                NaN                NaN                NaN                NaN
# 3                NaN                NaN                NaN                NaN
# 4                NaN                NaN                NaN                NaN
#
#    a_last_5_avrg_tklw  a_last_5_avrg_pkwon  a_last_5_avrg_pkcon  \
# 0                 NaN                  NaN                  NaN
# 1                 NaN                  NaN                  NaN
# 2                 NaN                  NaN                  NaN
# 3                 NaN                  NaN                  NaN
# 4                 NaN                  NaN                  NaN
#
#    a_last_5_avrg_og  a_last_5_avrg_recov  a_last_5_avrg_aer_won  \
# 0               NaN                  NaN                    NaN
# 1               NaN                  NaN                    NaN
# 2               NaN                  NaN                    NaN
# 3               NaN                  NaN                    NaN
# 4               NaN                  NaN                    NaN
#
#    a_last_5_avrg_aer_lost  a_last_3_avrg_gls  a_last_3_avrg_ast  \
# 0                     NaN                NaN                NaN
# 1                     NaN                NaN                NaN
# 2                     NaN                NaN                NaN
# 3                     NaN                NaN                NaN
# 4                     NaN                NaN                NaN
#
#    a_last_3_avrg_pk  a_last_3_avrg_pkatt  a_last_3_avrg_sh  a_last_3_avrg_sot  \
# 0               NaN                  NaN               NaN                NaN
# 1               NaN                  NaN               NaN                NaN
# 2               NaN                  NaN               NaN                NaN
# 3               NaN                  NaN               NaN                NaN
# 4               NaN                  NaN               NaN                NaN
#
#    a_last_3_avrg_yellow  a_last_3_avrg_red  a_last_3_touches  \
# 0                   NaN                NaN               NaN
# 1                   NaN                NaN               NaN
# 2                   NaN                NaN               NaN
# 3                   NaN                NaN               NaN
# 4                   NaN                NaN               NaN
#
#    a_last_3_avrg_press  a_last_3_avrg_tkl  a_last_3_avrg_int  \
# 0                  NaN                NaN                NaN
# 1                  NaN                NaN                NaN
# 2                  NaN                NaN                NaN
# 3                  NaN                NaN                NaN
# 4                  NaN                NaN                NaN
#
#    a_last_3_avrg_blk  a_last_3_avrg_xg  a_last_3_avrg_xa  a_last_3_avrg_sca  \
# 0                NaN               NaN               NaN                NaN
# 1                NaN               NaN               NaN                NaN
# 2                NaN               NaN               NaN                NaN
# 3                NaN               NaN               NaN                NaN
# 4                NaN               NaN               NaN                NaN
#
#    a_last_3_avrg_gca  a_last_3_avrg_cmp  a_last_3_avrg_pass_att  \
# 0                NaN                NaN                     NaN
# 1                NaN                NaN                     NaN
# 2                NaN                NaN                     NaN
# 3                NaN                NaN                     NaN
# 4                NaN                NaN                     NaN
#
#    a_last_3_avrg_pass_prog  a_last_3_avrg_carries  a_last_3_avrg_carries_prog  \
# 0                      NaN                    NaN                         NaN
# 1                      NaN                    NaN                         NaN
# 2                      NaN                    NaN                         NaN
# 3                      NaN                    NaN                         NaN
# 4                      NaN                    NaN                         NaN
#
#    a_last_3_avrg_dri_succ  a_last_3_avrg_dri_att  a_last_3_avrg_yellow2  \
# 0                     NaN                    NaN                    NaN
# 1                     NaN                    NaN                    NaN
# 2                     NaN                    NaN                    NaN
# 3                     NaN                    NaN                    NaN
# 4                     NaN                    NaN                    NaN
#
#    last_3_avrg_fls_y  a_last_3_avrg_fld  a_last_3_avrg_off  a_last_3_avrg_crs  \
# 0                NaN                NaN                NaN                NaN
# 1                NaN                NaN                NaN                NaN
# 2                NaN                NaN                NaN                NaN
# 3                NaN                NaN                NaN                NaN
# 4                NaN                NaN                NaN                NaN
#
#    a_last_3_avrg_tklw  a_last_3_avrg_pkwon  a_last_3_avrg_pkcon  \
# 0                 NaN                  NaN                  NaN
# 1                 NaN                  NaN                  NaN
# 2                 NaN                  NaN                  NaN
# 3                 NaN                  NaN                  NaN
# 4                 NaN                  NaN                  NaN
#
#    a_last_3_avrg_og  a_last_3_avrg_recov  a_last_3_avrg_aer_won  \
# 0               NaN                  NaN                    NaN
# 1               NaN                  NaN                    NaN
# 2               NaN                  NaN                    NaN
# 3               NaN                  NaN                    NaN
# 4               NaN                  NaN                    NaN
#
#    a_last_3_avrg_aer_lost  result h_last5match  h_accumulatpts a_last5match  \
# 0                     NaN       0            N             0.0            N
# 1                     NaN       2            N             0.0            N
# 2                     NaN       2            N             0.0            N
# 3                     NaN       2            N             0.0            N
# 4                     NaN       0            N             0.0            N
#
#    a_accumulatpts  h_total_goals  a_total_goals  total_goals  \
# 0             0.0              4              3            7
# 1             0.0              0              3            3
# 2             0.0              2              3            5
# 3             0.0              0              2            2
# 4             0.0              1              0            1
#
#    h_total_value_eur  h_total_wage_eur  h_average_age  h_average_height_cm  \
# 0          434500000           2245000          26.28               181.11
# 1          158700000            840000          26.06               185.17
# 2          554500000           2630000          25.88               182.12
# 3           99450000            690000          27.12               182.47
# 4          128550000           1060000          27.67               185.06
#
#    h_average_weight_kg  h_average_overall  h_average_potential  h_int_rep  \
# 0                75.56              81.11                83.94       2.72
# 1                77.33              75.72                78.72       1.61
# 2                78.53              83.29                85.88       2.71
# 3                76.94              74.24                76.76       1.24
# 4                79.06              75.50                77.67       1.78
#
#    h_skill_moves  h_age_std  h_height_cm_std  h_weight_kg_std  h_overall_std  \
# 0           2.78       3.92             6.59             7.33           5.42
# 1           2.50       3.44             6.49             7.42           3.48
# 2           2.82       2.69             8.58             7.58           3.39
# 3           2.53       3.97             5.96             5.76           2.25
# 4           2.50       4.03             4.48             5.91           4.62
#
#    h_potential_std  h_int_repn_std  h_skills_moves_std  a_total_value_eur  \
# 0             3.21            0.96                0.81          183500000
# 1             4.01            0.70                0.71           78200000
# 2             3.48            0.77                0.88          103475000
# 3             3.47            0.44                0.87          544500000
# 4             3.77            0.55                0.71          115200000
#
#    a_total_wage_eur  a_average_age  a_average_height_cm  a_average_weight_kg  \
# 0           1000000          26.62               182.69                82.44
# 1            610000          25.76               185.00                77.82
# 2            810000          27.06               182.65                77.12
# 3           2755000          26.33               180.89                75.28
# 4            970000          26.28               180.06                75.44
#
#    a_average_overall  a_average_potential  a_average_int_rep  \
# 0              77.31                80.62               1.81
# 1              72.53                75.65               1.00
# 2              74.29                76.06               1.18
# 3              82.78                85.94               2.83
# 4              74.56                78.33               1.17
#
#    a_average_skill_moves  a_age_std  a_height_cm_std  a_weight_kg_std  \
# 0                   2.56       4.46             6.01             9.67
# 1                   2.53       2.25             7.26             6.72
# 2                   2.29       2.16             6.32             7.44
# 3                   3.00       4.06             6.71             8.57
# 4                   2.78       4.07             7.10             7.14
#
#    a_overall_std  a_potential_std  a_int_rep_std  a_skills_moves_std
# 0           3.96             3.84           0.75                0.89
# 1           2.74             3.76           0.00                0.80
# 2           2.76             2.59           0.39                0.59
# 3           3.47             4.18           0.86                0.97
# 4           3.15             3.69           0.51                0.73

# %% [markdown]
# The null values are from the last 5 or last 3 games stats. They are all at the first game each team played. This is due to no previous record for the last 5 games or last 3 games. We will be removing those matches in this case.

# %%
#Remove rows with null values
train = train.dropna(axis='rows')

# %%
#Checking for any remaining null values
train.isnull().sum()[train.isnull().sum()>0]
# Out:
# Series([], dtype: int64)

# %%
#After removing, we are left with 1307 rows.
train.shape
# Out:
# (1307, 264)

# %% [markdown]
# ### Home Total Goals Classes
#
# As we are predicting the number of home total goals and away total goals, we will be looking into the number of classes. The range is between 0 to 8 for home total goals. For away goals, it is 0 - 9. The data is very imbalanced, so we will remove some outliers.

# %%
#Looking at h_total_goals
train['h_total_goals'].value_counts()
# Out:
# 1    426
# 2    319
# 0    311
# 3    144
# 4     67
# 5     33
# 6      4
# 7      2
# 8      1
# Name: h_total_goals, dtype: int64

# %%
train.loc[train['h_total_goals'] >= 7]
# Out:
#             date                          match             home  \
# 70    2017-10-14  Manchester_City_vs_Stoke_City  Manchester City
# 813   2019-09-21     Manchester_City_vs_Watford  Manchester City
# 1176  2020-10-04       Aston_Villa_vs_Liverpool      Aston Villa
#
#                          stadium  attendance  h_gls  h_ast  h_pk  h_pkatt  \
# 70    Etihad Stadium, Manchester       54128      7      7     0        0
# 813   Etihad Stadium, Manchester       54273      8      4     1        1
# 1176       Villa Park Birmingham           0      7      6     0        0
#
#       h_sh  h_sot  h_yellow  h_red  h_touches  h_press  h_tkl  h_int  h_blk  \
# 70      21     12         0      0      972.0    135.0   12.0      4    9.0
# 813     27     11         2      0      869.0    127.0   21.0      3   12.0
# 1176    18     11         2      0      449.0    231.0   20.0      4   23.0
#
#       h_xg  h_npxg  h_xa  h_sca  h_gca  h_cmp  h_pass_att  h_pass_prog  \
# 70     3.0     3.0   2.7   36.0   13.0  805.0       891.0         81.0
# 813    5.8     5.1   4.0   49.0   15.0  691.0       774.0         64.0
# 1176   3.8     3.8   3.8   28.0   10.0  213.0       308.0         26.0
#
#       h_carries  h_carries_prog  h_dri_succ  h_dri_att  h_yellow2  h_fls  \
# 70        821.0            93.0         4.0        7.0          0      6
# 813       714.0            90.0        22.0       26.0          0      5
# 1176      238.0            34.0        14.0       23.0          0      9
#
#       h_fld  h_off  h_crs  h_tklw  h_pkwon  h_pkcon  h_og  h_recov  h_aer_won  \
# 70        9      2     14      10      0.0      0.0     1     85.0       10.0
# 813      12      2     17      13      1.0      0.0     0     86.0       11.0
# 1176     11      2     10      12      0.0      0.0     0    106.0       14.0
#
#       h_aer_lost  h_last_5_avrg_gls  h_last_5_avrg_ast  h_last_5_avrg_pk  \
# 70           7.0                3.8                3.6               0.2
# 813          4.0                3.2                3.0               0.2
# 1176        16.0                1.4                1.4               0.0
#
#       h_last_5_avrg_pkatt  h_last_5_avrg_sh  h_last_5_avrg_sot  \
# 70                    0.2              20.2                8.4
# 813                   0.2              20.0                7.0
# 1176                  0.0              13.4                3.0
#
#       h_last_5_avrg_yellow  h_last_5_avrg_red  h_last_5_touches  \
# 70                     2.4                0.2             813.2
# 813                    1.6                0.0             767.4
# 1176                   2.0                0.0             498.6
#
#       h_last_5_avrg_press  h_last_5_avrg_tkl  h_last_5_avrg_int  \
# 70                  120.4               12.4               11.0
# 813                 147.6               16.8                6.2
# 1176                102.8               15.2                4.2
#
#       h_last_5_avrg_blk  h_last_5_avrg_xg  h_last_5_avrg_xa  \
# 70                 13.0              2.54              1.84
# 813                13.0              2.52              1.84
# 1176               16.2              1.16              1.00
#
#       h_last_5_avrg_sca  h_last_5_avrg_gca  h_last_5_avrg_cmp  \
# 70                 32.2                7.6              609.8
# 813                32.6                6.0              576.4
# 1176               22.8                2.6              299.4
#
#       h_last_5_avrg_pass_att  h_last_5_avrg_pass_prog  h_last_5_avrg_carries  \
# 70                     698.2                     54.2                  580.0
# 813                    662.8                     52.6                  540.4
# 1176                   395.4                     29.0                  295.8
#
#       h_last_5_avrg_carries_prog  h_last_5_avrg_dri_succ  \
# 70                          74.4                     9.2
# 813                         84.2                    12.8
# 1176                        34.6                     6.4
#
#       h_last_5_avrg_dri_att  h_last_5_avrg_yellow2  h_last_5_avrg_fls  \
# 70                     15.6                    0.2               11.2
# 813                    20.0                    0.0               12.4
# 1176                    9.0                    0.0               14.8
#
#       h_last_5_avrg_fld  h_last_5_avrg_off  h_last_5_avrg_crs  \
# 70                 11.0                1.6               18.4
# 813                 9.6                2.4               12.6
# 1176               17.0                1.2               15.2
#
#       h_last_5_avrg_tklw  h_last_5_avrg_pkwon  h_last_5_avrg_pkcon  \
# 70                   8.8                  0.2                  0.0
# 813                 10.6                  0.2                  0.0
# 1176                 8.4                  0.0                  0.2
#
#       h_last_5_avrg_og  h_last_5_avrg_recov  h_last_5_avrg_aer_won  \
# 70                 0.0                 91.0                   12.6
# 813                0.0                 90.6                   13.4
# 1176               0.0                 80.6                   18.8
#
#       h_last_5_avrg_aer_lost  h_last_3_avrg_gls  h_last_3_avrg_ast  \
# 70                       5.6           4.000000           3.666667
# 813                     10.2           3.000000           3.000000
# 1176                    22.0           1.666667           1.666667
#
#       h_last_3_avrg_pk  h_last_3_avrg_pkatt  h_last_3_avrg_sh  \
# 70            0.333333             0.333333         23.333333
# 813           0.000000             0.000000         19.000000
# 1176          0.000000             0.000000         14.333333
#
#       h_last_3_avrg_sot  h_last_3_avrg_yellow  h_last_3_avrg_red  \
# 70             8.000000              1.666667                0.0
# 813            6.333333              1.666667                0.0
# 1176           3.666667              2.333333                0.0
#
#       h_last_3_touches  h_last_3_avrg_press  h_last_3_avrg_tkl  \
# 70          807.000000           103.333333          13.333333
# 813         797.000000           136.333333          14.333333
# 1176        526.333333           108.666667          14.333333
#
#       h_last_3_avrg_int  h_last_3_avrg_blk  h_last_3_avrg_xg  \
# 70            10.000000          13.666667          2.800000
# 813            4.666667          13.333333          2.200000
# 1176           5.000000          16.000000          1.266667
#
#       h_last_3_avrg_xa  h_last_3_avrg_sca  h_last_3_avrg_gca  \
# 70            1.800000          37.333333           8.000000
# 813           1.666667          29.666667           5.666667
# 1176          1.033333          25.333333           3.000000
#
#       h_last_3_avrg_cmp  h_last_3_avrg_pass_att  h_last_3_avrg_pass_prog  \
# 70           609.333333              693.666667                60.000000
# 813          607.333333              700.333333                51.333333
# 1176         322.333333              422.666667                29.333333
#
#       h_last_3_avrg_carries  h_last_3_avrg_carries_prog  \
# 70               579.333333                   77.666667
# 813              590.333333                   90.333333
# 1176             318.666667                   36.000000
#
#       h_last_3_avrg_dri_succ  h_last_3_avrg_dri_att  h_last_3_avrg_yellow2  \
# 70                 10.000000              16.333333                    0.0
# 813                14.333333              21.666667                    0.0
# 1176                6.000000               9.333333                    0.0
#
#       h_last_3_avrg_fls  h_last_3_avrg_fld  h_last_3_avrg_off  \
# 70            10.333333          10.000000           0.000000
# 813           10.333333          10.333333           1.666667
# 1176          15.000000          17.000000           1.666667
#
#       h_last_3_avrg_crs  h_last_3_avrg_tklw  h_last_3_avrg_pkwon  \
# 70            18.000000           10.000000             0.333333
# 813           11.666667            8.666667             0.000000
# 1176          16.333333            7.333333             0.000000
#
#       h_last_3_avrg_pkcon  h_last_3_avrg_og  h_last_3_avrg_recov  \
# 70               0.000000               0.0            88.666667
# 813              0.000000               0.0            92.333333
# 1176             0.333333               0.0            85.333333
#
#       h_last_3_avrg_aer_won  h_last_3_avrg_aer_lost        away  a_gls  a_ast  \
# 70                 9.333333                5.000000  Stoke City      1      1
# 813               11.666667                9.666667     Watford      0      0
# 1176              21.333333               22.666667   Liverpool      2      1
#
#       a_pk  a_pkatt  a_sh  a_sot  a_yellow  a_red  a_touches  a_press  a_tkl  \
# 70       0        0     5      2         1      0      322.0     96.0   12.0
# 813      0        0     5      4         2      0      457.0    294.0   14.0
# 1176     0        0    14      8         1      0      786.0    149.0   21.0
#
#       a_int  a_blk  a_xg  a_npxg  a_xa  a_sca  a_gca  a_cmp  a_pass_att  \
# 70       11   16.0   0.4     0.4   0.4   10.0    4.0  164.0       231.0
# 813       7   15.0   0.3     0.3   0.4    9.0    0.0  281.0       361.0
# 1176      4   16.0   1.6     1.6   1.4   21.0    1.0  564.0       674.0
#
#       a_pass_prog  a_carries  a_carries_prog  a_dri_succ  a_dri_att  \
# 70           14.0      189.0            11.0         6.0       11.0
# 813          14.0      306.0            14.0         7.0       18.0
# 1176         51.0      509.0            57.0        16.0       21.0
#
#       a_yellow2  a_fls  a_fld  a_off  a_crs  a_tklw  a_pwon  a_pkcon  a_og  \
# 70            0      9      6      1      2       7     0.0      0.0     0
# 813           0     12      5      2      2       7     0.0      1.0     0
# 1176          0     11      8      1     12       9     0.0      0.0     0
#
#       a_recov  a_aer_won  a_aer_lost  a_last_5_avrg_gls  a_last_5_avrg_ast  \
# 70       66.0        7.0        10.0                1.2                1.0
# 813      61.0        4.0        11.0                0.8                0.4
# 1176    101.0       16.0        14.0                3.4                1.8
#
#       a_last_5_avrg_pk  a_last_5_avrg_pkatt  a_last_5_avrg_sh  \
# 70                 0.0                  0.2              12.2
# 813                0.2                  0.2              16.6
# 1176               0.4                  0.4              16.4
#
#       a_last_5_avrg_sot  a_last_5_avrg_yellow  a_last_5_avrg_red  \
# 70                  3.6                   1.2                0.0
# 813                 4.0                   2.0                0.0
# 1176                6.2                   0.8                0.0
#
#       a_last_5_touches  a_last_5_avrg_press  a_last_5_avrg_tkl  \
# 70               515.6                 93.6               15.0
# 813              607.6                176.4               18.6
# 1176             817.4                139.8               14.6
#
#       a_last_5_avrg_int  a_last_5_avrg_blk  a_last_5_avrg_xg  \
# 70                  7.6               16.4              1.18
# 813                 8.2               18.0              1.64
# 1176                5.8               11.2              2.18
#
#       a_last_5_avrg_xa  a_last_5_avrg_sca  a_last_5_avrg_gca  \
# 70                0.56               19.4                1.8
# 813               1.06               26.2                1.2
# 1176              1.10               23.8                4.4
#
#       a_last_5_avrg_cmp  a_last_5_avrg_pass_att  a_last_5_avrg_pass_prog  \
# 70                297.8                   399.4                     33.8
# 813               388.4                   487.0                     37.4
# 1176              600.0                   709.6                     51.2
#
#       a_last_5_avrg_carries  a_last_5_avrg_carries_prog  \
# 70                    298.2                        35.4
# 813                   391.8                        47.2
# 1176                  551.4                        51.0
#
#       a_last_5_avrg_dri_succ  a_last_5_avrg_dri_att  a_last_5_avrg_yellow2  \
# 70                      10.8                   17.2                    0.0
# 813                     12.6                   19.6                    0.0
# 1176                    14.2                   23.8                    0.0
#
#       a_last_5_avrg_fls  a_last_5_avrg_fld  a_last_5_avrg_off  \
# 70                 10.6               11.2                0.6
# 813                15.0               10.6                0.6
# 1176                9.4               10.6                0.8
#
#       a_last_5_avrg_crs  a_last_5_avrg_tklw  a_last_5_avrg_pkwon  \
# 70                 11.0                 8.2                  0.2
# 813                11.4                11.8                  0.2
# 1176               11.8                 9.6                  0.2
#
#       a_last_5_avrg_pkcon  a_last_5_avrg_og  a_last_5_avrg_recov  \
# 70                    0.0               0.0                 89.6
# 813                   0.2               0.2                 90.0
# 1176                  0.2               0.0                109.4
#
#       a_last_5_avrg_aer_won  a_last_5_avrg_aer_lost  a_last_3_avrg_gls  \
# 70                     13.6                    13.6           1.000000
# 813                    14.8                    17.4           1.333333
# 1176                   12.2                    13.8           3.000000
#
#       a_last_3_avrg_ast  a_last_3_avrg_pk  a_last_3_avrg_pkatt  \
# 70             1.000000          0.000000             0.333333
# 813            0.666667          0.333333             0.333333
# 1176           1.000000          0.666667             0.666667
#
#       a_last_3_avrg_sh  a_last_3_avrg_sot  a_last_3_avrg_yellow  \
# 70           12.333333           3.666667              1.333333
# 813          21.333333           5.000000              2.333333
# 1176         19.333333           6.000000              1.000000
#
#       a_last_3_avrg_red  a_last_3_touches  a_last_3_avrg_press  \
# 70                  0.0        499.000000            79.666667
# 813                 0.0        632.666667           161.000000
# 1176                0.0        810.666667           155.000000
#
#       a_last_3_avrg_tkl  a_last_3_avrg_int  a_last_3_avrg_blk  \
# 70            13.333333           9.000000          16.333333
# 813           17.333333           7.333333          17.000000
# 1176          14.666667           7.000000          12.333333
#
#       a_last_3_avrg_xg  a_last_3_avrg_xa  a_last_3_avrg_sca  \
# 70            1.266667          0.500000          18.666667
# 813           2.100000          1.333333          35.333333
# 1176          2.966667          1.300000          28.666667
#
#       a_last_3_avrg_gca  a_last_3_avrg_cmp  a_last_3_avrg_pass_att  \
# 70             1.666667         276.000000              387.333333
# 813            2.000000         423.000000              516.333333
# 1176           3.000000         591.666667              699.666667
#
#       a_last_3_avrg_pass_prog  a_last_3_avrg_carries  \
# 70                  34.666667             283.333333
# 813                 40.666667             420.333333
# 1176                57.333333             534.666667
#
#       a_last_3_avrg_carries_prog  a_last_3_avrg_dri_succ  \
# 70                     32.000000                7.000000
# 813                    56.333333               13.666667
# 1176                   54.333333               12.666667
#
#       a_last_3_avrg_dri_att  a_last_3_avrg_yellow2  last_3_avrg_fls_y  \
# 70                13.666667                    0.0          10.333333
# 813               20.000000                    0.0          16.000000
# 1176              19.333333                    0.0          10.000000
#
#       a_last_3_avrg_fld  a_last_3_avrg_off  a_last_3_avrg_crs  \
# 70            11.666667           0.666667          10.666667
# 813            9.666667           0.666667          12.000000
# 1176           9.666667           1.000000          13.666667
#
#       a_last_3_avrg_tklw  a_last_3_avrg_pkwon  a_last_3_avrg_pkcon  \
# 70              8.333333             0.333333             0.000000
# 813            11.666667             0.333333             0.333333
# 1176           10.333333             0.333333             0.333333
#
#       a_last_3_avrg_og  a_last_3_avrg_recov  a_last_3_avrg_aer_won  \
# 70                 0.0            97.333333                    9.0
# 813                0.0            89.333333                   13.0
# 1176               0.0           109.333333                    8.0
#
#       a_last_3_avrg_aer_lost  result h_last5match  h_accumulatpts  \
# 70                 13.333333       0        WWWWW            19.0
# 813                15.000000       0        WDWWL           208.0
# 1176               11.666667       0        DWDWW            41.0
#
#      a_last5match  a_accumulatpts  h_total_goals  a_total_goals  total_goals  \
# 70          DDLLW             8.0              7              2            9
# 813         LLLDD            93.0              8              0            8
# 1176        WWWWW           280.0              7              2            9
#
#       h_total_value_eur  h_total_wage_eur  h_average_age  h_average_height_cm  \
# 70            544500000           2755000          26.33               180.89
# 813           695500000           3260000          26.39               179.39
# 1176          141370000            751000          24.89               183.00
#
#       h_average_weight_kg  h_average_overall  h_average_potential  h_int_rep  \
# 70                  75.28              82.78                85.94       2.83
# 813                 72.67              84.50                87.50       2.56
# 1176                75.22              74.00                79.00       1.22
#
#       h_skill_moves  h_age_std  h_height_cm_std  h_weight_kg_std  \
# 70             3.00       4.06             6.71             8.57
# 813            3.39       4.10             6.28             7.05
# 1176           2.94       2.93             5.86             8.80
#
#       h_overall_std  h_potential_std  h_int_repn_std  h_skills_moves_std  \
# 70             3.47             4.18            0.86                0.97
# 813            3.90             2.71            0.92                0.98
# 1176           5.21             3.24            0.55                0.80
#
#       a_total_value_eur  a_total_wage_eur  a_average_age  a_average_height_cm  \
# 70            173000000           1010000          26.75               185.06
# 813           179300000           1040000          27.89               184.17
# 1176          684950000           2391000          26.50               179.67
#
#       a_average_weight_kg  a_average_overall  a_average_potential  \
# 70                  80.44              77.31                80.19
# 813                 78.50              77.39                79.11
# 1176                73.22              83.50                86.22
#
#       a_average_int_rep  a_average_skill_moves  a_age_std  a_height_cm_std  \
# 70                 2.00                   2.69       4.22             8.74
# 813                1.61                   2.83       3.45             5.45
# 1176               2.39                   3.50       3.50             7.02
#
#       a_weight_kg_std  a_overall_std  a_potential_std  a_int_rep_std  \
# 70               8.96           2.27             4.23           0.37
# 813              7.72           2.15             3.46           0.70
# 1176             7.69           6.17             3.62           0.70
#
#       a_skills_moves_std
# 70                  0.95
# 813                 0.86
# 1176                1.04

# %% [markdown]
# We will be dropping matches with home total goals more than 7. We will do the same for matches with more than 7 away total goals.

# %%
#Removing rows that are outliers
train.drop(labels=[70,850,813,1176,1268],axis=0,inplace=True)

# %%
train['h_total_goals'].value_counts()
# Out:
# 1    426
# 2    319
# 0    309
# 3    144
# 4     67
# 5     33
# 6      4
# Name: h_total_goals, dtype: int64

# %% [markdown]
# ### Removing Features that will be Irrelevant
#
# We will ready the features that will be used to train the model for home total goals.
#
# #### Home Total Goals Dataset

# %%
train.head()
# Out:
#           date                              match          home  \
# 10  2017-08-19     Southampton_vs_West_Ham_United   Southampton
# 11  2017-08-19  Swansea_City_vs_Manchester_United  Swansea City
# 12  2017-08-19              Stoke_City_vs_Arsenal    Stoke City
# 13  2017-08-19    Burnley_vs_West_Bromwich_Albion       Burnley
# 14  2017-08-19             Bournemouth_vs_Watford   Bournemouth
#
#                                 stadium  attendance  h_gls  h_ast  h_pk  \
# 10      St. Mary's Stadium, Southampton       31424      3      1     2
# 11  Liberty Stadium, Swansea, Glamorgan       20862      0      0     0
# 12       Bet365 Stadium, Stoke-on-Trent       29459      1      1     0
# 13                   Turf Moor, Burnley       19619      0      0     0
# 14        Vitality Stadium, Bournemouth       10501      0      0     0
#
#     h_pkatt  h_sh  h_sot  h_yellow  h_red  h_touches  h_press  h_tkl  h_int  \
# 10        2    12      3         1      0      705.0    121.0   13.0      7
# 11        0     6      0         1      0      558.0    149.0   24.0     13
# 12        0    10      4         0      0      338.0    129.0   12.0      2
# 13        0    21      1         1      0      629.0     92.0    9.0      4
# 14        0     6      2         1      0      571.0     64.0   11.0      7
#
#     h_blk  h_xg  h_npxg  h_xa  h_sca  h_gca  h_cmp  h_pass_att  h_pass_prog  \
# 10   11.0   2.1     0.5   0.3   28.0    6.0  504.0       619.0         54.0
# 11    7.0   0.3     0.3   0.3    7.0    0.0  336.0       440.0         26.0
# 12   24.0   0.6     0.6   0.6   16.0    2.0  136.0       221.0         18.0
# 13   12.0   1.4     1.4   1.0   23.0    0.0  409.0       540.0         39.0
# 14   20.0   1.4     1.4   0.6    7.0    0.0  338.0       460.0         32.0
#
#     h_carries  h_carries_prog  h_dri_succ  h_dri_att  h_yellow2  h_fls  h_fld  \
# 10      461.0            78.0        10.0       13.0          0     20     10
# 11      373.0            39.0         3.0        6.0          0     14     11
# 12      165.0            18.0         4.0       10.0          0      8     10
# 13      419.0            43.0         9.0       13.0          0     11     13
# 14      329.0            37.0         7.0        9.0          0      6     14
#
#     h_off  h_crs  h_tklw  h_pkwon  h_pkcon  h_og  h_recov  h_aer_won  \
# 10      1     17      10      2.0      0.0     0    103.0       16.0
# 11      1     16      13      0.0      0.0     0     85.0       17.0
# 12      4     10       5      0.0      0.0     0     82.0        8.0
# 13      1     22       6      0.0      0.0     0    123.0       17.0
# 14      1     15       4      0.0      0.0     0     96.0        5.0
#
#     h_aer_lost  h_last_5_avrg_gls  h_last_5_avrg_ast  h_last_5_avrg_pk  \
# 10        31.0                0.0                0.0               0.0
# 11         4.0                0.0                0.0               0.0
# 12         5.0                0.0                0.0               0.0
# 13        12.0                3.0                3.0               0.0
# 14        10.0                0.0                0.0               0.0
#
#     h_last_5_avrg_pkatt  h_last_5_avrg_sh  h_last_5_avrg_sot  \
# 10                  0.0              30.0                3.0
# 11                  0.0               4.0                0.0
# 12                  0.0              10.0                1.0
# 13                  0.0              10.0                5.0
# 14                  0.0               9.0                2.0
#
#     h_last_5_avrg_yellow  h_last_5_avrg_red  h_last_5_touches  \
# 10                   2.0                0.0             645.0
# 11                   1.0                0.0             490.0
# 12                   1.0                0.0             478.0
# 13                   3.0                0.0             447.0
# 14                   1.0                0.0             739.0
#
#     h_last_5_avrg_press  h_last_5_avrg_tkl  h_last_5_avrg_int  \
# 10                 95.0               10.0               12.0
# 11                 64.0                7.0               16.0
# 12                 58.0               14.0               12.0
# 13                116.0                7.0               10.0
# 14                114.0               20.0                0.0
#
#     h_last_5_avrg_blk  h_last_5_avrg_xg  h_last_5_avrg_xa  h_last_5_avrg_sca  \
# 10               10.0               2.0               1.5               47.0
# 11               28.0               0.4               0.3                7.0
# 12               16.0               0.1               0.1               15.0
# 13               20.0               0.8               0.6               16.0
# 14               13.0               0.4               0.3               14.0
#
#     h_last_5_avrg_gca  h_last_5_avrg_cmp  h_last_5_avrg_pass_att  \
# 10                0.0              437.0                   549.0
# 11                0.0              292.0                   383.0
# 12                0.0              229.0                   361.0
# 13                6.0              248.0                   344.0
# 14                0.0              530.0                   642.0
#
#     h_last_5_avrg_pass_prog  h_last_5_avrg_carries  \
# 10                     41.0                  439.0
# 11                     21.0                  304.0
# 12                     33.0                  269.0
# 13                     23.0                  235.0
# 14                     41.0                  589.0
#
#     h_last_5_avrg_carries_prog  h_last_5_avrg_dri_succ  h_last_5_avrg_dri_att  \
# 10                        60.0                    10.0                   10.0
# 11                        17.0                     6.0                    7.0
# 12                        36.0                    12.0                   16.0
# 13                        23.0                     3.0                    4.0
# 14                        55.0                    13.0                   21.0
#
#     h_last_5_avrg_yellow2  h_last_5_avrg_fls  h_last_5_avrg_fld  \
# 10                    0.0               11.0               14.0
# 11                    0.0               15.0               11.0
# 12                    0.0               12.0               15.0
# 13                    0.0               14.0               16.0
# 14                    0.0                3.0               21.0
#
#     h_last_5_avrg_off  h_last_5_avrg_crs  h_last_5_avrg_tklw  \
# 10                0.0               22.0                 7.0
# 11                1.0                9.0                 3.0
# 12                6.0               13.0                 9.0
# 13                1.0                7.0                 4.0
# 14                0.0               21.0                11.0
#
#     h_last_5_avrg_pkwon  h_last_5_avrg_pkcon  h_last_5_avrg_og  \
# 10                  0.0                  0.0               0.0
# 11                  0.0                  0.0               0.0
# 12                  0.0                  0.0               0.0
# 13                  0.0                  0.0               0.0
# 14                  0.0                  0.0               0.0
#
#     h_last_5_avrg_recov  h_last_5_avrg_aer_won  h_last_5_avrg_aer_lost  \
# 10                102.0                   11.0                     8.0
# 11                 70.0                    8.0                    11.0
# 12                110.0                   21.0                     9.0
# 13                 88.0                   14.0                     8.0
# 14                110.0                   10.0                     9.0
#
#     h_last_3_avrg_gls  h_last_3_avrg_ast  h_last_3_avrg_pk  \
# 10                0.0                0.0               0.0
# 11                0.0                0.0               0.0
# 12                0.0                0.0               0.0
# 13                3.0                3.0               0.0
# 14                0.0                0.0               0.0
#
#     h_last_3_avrg_pkatt  h_last_3_avrg_sh  h_last_3_avrg_sot  \
# 10                  0.0              30.0                3.0
# 11                  0.0               4.0                0.0
# 12                  0.0              10.0                1.0
# 13                  0.0              10.0                5.0
# 14                  0.0               9.0                2.0
#
#     h_last_3_avrg_yellow  h_last_3_avrg_red  h_last_3_touches  \
# 10                   2.0                0.0             645.0
# 11                   1.0                0.0             490.0
# 12                   1.0                0.0             478.0
# 13                   3.0                0.0             447.0
# 14                   1.0                0.0             739.0
#
#     h_last_3_avrg_press  h_last_3_avrg_tkl  h_last_3_avrg_int  \
# 10                 95.0               10.0               12.0
# 11                 64.0                7.0               16.0
# 12                 58.0               14.0               12.0
# 13                116.0                7.0               10.0
# 14                114.0               20.0                0.0
#
#     h_last_3_avrg_blk  h_last_3_avrg_xg  h_last_3_avrg_xa  h_last_3_avrg_sca  \
# 10               10.0               2.0               1.5               47.0
# 11               28.0               0.4               0.3                7.0
# 12               16.0               0.1               0.1               15.0
# 13               20.0               0.8               0.6               16.0
# 14               13.0               0.4               0.3               14.0
#
#     h_last_3_avrg_gca  h_last_3_avrg_cmp  h_last_3_avrg_pass_att  \
# 10                0.0              437.0                   549.0
# 11                0.0              292.0                   383.0
# 12                0.0              229.0                   361.0
# 13                6.0              248.0                   344.0
# 14                0.0              530.0                   642.0
#
#     h_last_3_avrg_pass_prog  h_last_3_avrg_carries  \
# 10                     41.0                  439.0
# 11                     21.0                  304.0
# 12                     33.0                  269.0
# 13                     23.0                  235.0
# 14                     41.0                  589.0
#
#     h_last_3_avrg_carries_prog  h_last_3_avrg_dri_succ  h_last_3_avrg_dri_att  \
# 10                        60.0                    10.0                   10.0
# 11                        17.0                     6.0                    7.0
# 12                        36.0                    12.0                   16.0
# 13                        23.0                     3.0                    4.0
# 14                        55.0                    13.0                   21.0
#
#     h_last_3_avrg_yellow2  h_last_3_avrg_fls  h_last_3_avrg_fld  \
# 10                    0.0               11.0               14.0
# 11                    0.0               15.0               11.0
# 12                    0.0               12.0               15.0
# 13                    0.0               14.0               16.0
# 14                    0.0                3.0               21.0
#
#     h_last_3_avrg_off  h_last_3_avrg_crs  h_last_3_avrg_tklw  \
# 10                0.0               22.0                 7.0
# 11                1.0                9.0                 3.0
# 12                6.0               13.0                 9.0
# 13                1.0                7.0                 4.0
# 14                0.0               21.0                11.0
#
#     h_last_3_avrg_pkwon  h_last_3_avrg_pkcon  h_last_3_avrg_og  \
# 10                  0.0                  0.0               0.0
# 11                  0.0                  0.0               0.0
# 12                  0.0                  0.0               0.0
# 13                  0.0                  0.0               0.0
# 14                  0.0                  0.0               0.0
#
#     h_last_3_avrg_recov  h_last_3_avrg_aer_won  h_last_3_avrg_aer_lost  \
# 10                102.0                   11.0                     8.0
# 11                 70.0                    8.0                    11.0
# 12                110.0                   21.0                     9.0
# 13                 88.0                   14.0                     8.0
# 14                110.0                   10.0                     9.0
#
#                     away  a_gls  a_ast  a_pk  a_pkatt  a_sh  a_sot  a_yellow  \
# 10       West Ham United      2      0     0        0    15      8         1
# 11     Manchester United      4      3     0        0    18      8         1
# 12               Arsenal      0      0     0        0    19      6         0
# 13  West Bromwich Albion      1      1     0        0     8      2         0
# 14               Watford      2      0     0        0    18      6         3
#
#     a_red  a_touches  a_press  a_tkl  a_int  a_blk  a_xg  a_npxg  a_xa  a_sca  \
# 10      1      428.0    138.0   15.0      8   10.0   1.7     1.7   0.7   21.0
# 11      0      738.0    122.0   14.0     37   18.0   2.7     2.7   1.4   29.0
# 12      0      842.0     73.0    8.0      4    8.0   1.1     1.1   1.1   27.0
# 13      1      373.0     70.0    8.0     12   19.0   0.7     0.7   0.7   11.0
# 14      0      517.0    111.0   13.0     15   15.0   1.7     1.7   0.8   26.0
#
#     a_gca  a_cmp  a_pass_att  a_pass_prog  a_carries  a_carries_prog  \
# 10    2.0  219.0       326.0         14.0      193.0            10.0
# 11    6.0  515.0       609.0         30.0      553.0            70.0
# 12    0.0  639.0       745.0         72.0      575.0            81.0
# 13    2.0  142.0       256.0         11.0      161.0            11.0
# 14    0.0  288.0       403.0         40.0      282.0            40.0
#
#     a_dri_succ  a_dri_att  a_yellow2  a_fls  a_fld  a_off  a_crs  a_tklw  \
# 10         6.0        9.0          0      9     20      0      6      13
# 11        10.0       21.0          0     11     14      0     15      10
# 12        10.0       15.0          0     10      8      3     17       5
# 13         6.0       11.0          0     12     11      3      7       2
# 14        12.0       21.0          0     16      6      7     24      11
#
#     a_pwon  a_pkcon  a_og  a_recov  a_aer_won  a_aer_lost  a_last_5_avrg_gls  \
# 10     0.0      2.0     0     88.0       31.0        16.0                0.0
# 11     0.0      0.0     0     66.0        4.0        17.0                4.0
# 12     0.0      0.0     0    102.0        5.0         8.0                4.0
# 13     0.0      0.0     0     89.0       12.0        17.0                1.0
# 14     0.0      0.0     0    110.0       10.0         5.0                3.0
#
#     a_last_5_avrg_ast  a_last_5_avrg_pk  a_last_5_avrg_pkatt  \
# 10                0.0               0.0                  0.0
# 11                4.0               0.0                  0.0
# 12                4.0               0.0                  0.0
# 13                1.0               0.0                  0.0
# 14                1.0               0.0                  0.0
#
#     a_last_5_avrg_sh  a_last_5_avrg_sot  a_last_5_avrg_yellow  \
# 10              10.0                1.0                   2.0
# 11              22.0                5.0                   2.0
# 12              28.0               10.0                   0.0
# 13              17.0                6.0                   3.0
# 14               9.0                5.0                   0.0
#
#     a_last_5_avrg_red  a_last_5_touches  a_last_5_avrg_press  \
# 10                0.0             544.0                 47.0
# 11                0.0             636.0                152.0
# 12                0.0             782.0                162.0
# 13                0.0             399.0                136.0
# 14                0.0             563.0                109.0
#
#     a_last_5_avrg_tkl  a_last_5_avrg_int  a_last_5_avrg_blk  a_last_5_avrg_xg  \
# 10               17.0               10.0               20.0               0.6
# 11               14.0                2.0               14.0               2.0
# 12               20.0                9.0               11.0               2.2
# 13               15.0                9.0               17.0               1.1
# 14               15.0               13.0               18.0               1.9
#
#     a_last_5_avrg_xa  a_last_5_avrg_sca  a_last_5_avrg_gca  a_last_5_avrg_cmp  \
# 10               0.5               16.0                0.0              327.0
# 11               2.1               32.0                7.0              429.0
# 12               2.2               51.0                7.0              546.0
# 13               0.9               25.0                2.0              188.0
# 14               0.3               11.0                3.0              301.0
#
#     a_last_5_avrg_pass_att  a_last_5_avrg_pass_prog  a_last_5_avrg_carries  \
# 10                   425.0                     38.0                  339.0
# 11                   524.0                     44.0                  409.0
# 12                   659.0                     50.0                  593.0
# 13                   294.0                     14.0                  218.0
# 14                   450.0                     24.0                  337.0
#
#     a_last_5_avrg_carries_prog  a_last_5_avrg_dri_succ  a_last_5_avrg_dri_att  \
# 10                        20.0                     1.0                    3.0
# 11                        52.0                    16.0                   23.0
# 12                        90.0                    15.0                   20.0
# 13                        21.0                     3.0                    9.0
# 14                        20.0                    12.0                   17.0
#
#     a_last_5_avrg_yellow2  a_last_5_avrg_fls  a_last_5_avrg_fld  \
# 10                    0.0               10.0               19.0
# 11                    0.0               19.0               10.0
# 12                    0.0                9.0               13.0
# 13                    0.0               21.0                2.0
# 14                    0.0               16.0               10.0
#
#     a_last_5_avrg_off  a_last_5_avrg_crs  a_last_5_avrg_tklw  \
# 10                4.0               11.0                10.0
# 11                1.0               11.0                 7.0
# 12                5.0               15.0                13.0
# 13                2.0               13.0                12.0
# 14                3.0               13.0                12.0
#
#     a_last_5_avrg_pkwon  a_last_5_avrg_pkcon  a_last_5_avrg_og  \
# 10                  0.0                  0.0               0.0
# 11                  0.0                  0.0               0.0
# 12                  0.0                  0.0               0.0
# 13                  0.0                  0.0               0.0
# 14                  0.0                  1.0               0.0
#
#     a_last_5_avrg_recov  a_last_5_avrg_aer_won  a_last_5_avrg_aer_lost  \
# 10                 88.0                    8.0                    13.0
# 11                 97.0                   13.0                     8.0
# 12                113.0                   11.0                     7.0
# 13                 94.0                    9.0                    10.0
# 14                116.0                   15.0                    13.0
#
#     a_last_3_avrg_gls  a_last_3_avrg_ast  a_last_3_avrg_pk  \
# 10                0.0                0.0               0.0
# 11                4.0                4.0               0.0
# 12                4.0                4.0               0.0
# 13                1.0                1.0               0.0
# 14                3.0                1.0               0.0
#
#     a_last_3_avrg_pkatt  a_last_3_avrg_sh  a_last_3_avrg_sot  \
# 10                  0.0              10.0                1.0
# 11                  0.0              22.0                5.0
# 12                  0.0              28.0               10.0
# 13                  0.0              17.0                6.0
# 14                  0.0               9.0                5.0
#
#     a_last_3_avrg_yellow  a_last_3_avrg_red  a_last_3_touches  \
# 10                   2.0                0.0             544.0
# 11                   2.0                0.0             636.0
# 12                   0.0                0.0             782.0
# 13                   3.0                0.0             399.0
# 14                   0.0                0.0             563.0
#
#     a_last_3_avrg_press  a_last_3_avrg_tkl  a_last_3_avrg_int  \
# 10                 47.0               17.0               10.0
# 11                152.0               14.0                2.0
# 12                162.0               20.0                9.0
# 13                136.0               15.0                9.0
# 14                109.0               15.0               13.0
#
#     a_last_3_avrg_blk  a_last_3_avrg_xg  a_last_3_avrg_xa  a_last_3_avrg_sca  \
# 10               20.0               0.6               0.5               16.0
# 11               14.0               2.0               2.1               32.0
# 12               11.0               2.2               2.2               51.0
# 13               17.0               1.1               0.9               25.0
# 14               18.0               1.9               0.3               11.0
#
#     a_last_3_avrg_gca  a_last_3_avrg_cmp  a_last_3_avrg_pass_att  \
# 10                0.0              327.0                   425.0
# 11                7.0              429.0                   524.0
# 12                7.0              546.0                   659.0
# 13                2.0              188.0                   294.0
# 14                3.0              301.0                   450.0
#
#     a_last_3_avrg_pass_prog  a_last_3_avrg_carries  \
# 10                     38.0                  339.0
# 11                     44.0                  409.0
# 12                     50.0                  593.0
# 13                     14.0                  218.0
# 14                     24.0                  337.0
#
#     a_last_3_avrg_carries_prog  a_last_3_avrg_dri_succ  a_last_3_avrg_dri_att  \
# 10                        20.0                     1.0                    3.0
# 11                        52.0                    16.0                   23.0
# 12                        90.0                    15.0                   20.0
# 13                        21.0                     3.0                    9.0
# 14                        20.0                    12.0                   17.0
#
#     a_last_3_avrg_yellow2  last_3_avrg_fls_y  a_last_3_avrg_fld  \
# 10                    0.0               10.0               19.0
# 11                    0.0               19.0               10.0
# 12                    0.0                9.0               13.0
# 13                    0.0               21.0                2.0
# 14                    0.0               16.0               10.0
#
#     a_last_3_avrg_off  a_last_3_avrg_crs  a_last_3_avrg_tklw  \
# 10                4.0               11.0                10.0
# 11                1.0               11.0                 7.0
# 12                5.0               15.0                13.0
# 13                2.0               13.0                12.0
# 14                3.0               13.0                12.0
#
#     a_last_3_avrg_pkwon  a_last_3_avrg_pkcon  a_last_3_avrg_og  \
# 10                  0.0                  0.0               0.0
# 11                  0.0                  0.0               0.0
# 12                  0.0                  0.0               0.0
# 13                  0.0                  0.0               0.0
# 14                  0.0                  1.0               0.0
#
#     a_last_3_avrg_recov  a_last_3_avrg_aer_won  a_last_3_avrg_aer_lost  \
# 10                 88.0                    8.0                    13.0
# 11                 97.0                   13.0                     8.0
# 12                113.0                   11.0                     7.0
# 13                 94.0                    9.0                    10.0
# 14                116.0                   15.0                    13.0
#
#     result h_last5match  h_accumulatpts a_last5match  a_accumulatpts  \
# 10       0            D             1.0            L             0.0
# 11       2            D             1.0            W             3.0
# 12       0            L             0.0            W             3.0
# 13       2            W             3.0            W             3.0
# 14       2            L             0.0            D             1.0
#
#     h_total_goals  a_total_goals  total_goals  h_total_value_eur  \
# 10              3              2            5          192000000
# 11              0              4            4          129600000
# 12              1              0            1          173000000
# 13              0              1            1          103475000
# 14              0              2            2          115200000
#
#     h_total_wage_eur  h_average_age  h_average_height_cm  h_average_weight_kg  \
# 10           1330000          25.61               182.28                76.78
# 11            970000          26.35               182.29                78.59
# 12           1010000          26.75               185.06                80.44
# 13            810000          27.06               182.65                77.12
# 14            970000          26.28               180.06                75.44
#
#     h_average_overall  h_average_potential  h_int_rep  h_skill_moves  \
# 10              77.17                80.44       1.78           2.61
# 11              75.53                78.41       1.76           2.88
# 12              77.31                80.19       2.00           2.69
# 13              74.29                76.06       1.18           2.29
# 14              74.56                78.33       1.17           2.78
#
#     h_age_std  h_height_cm_std  h_weight_kg_std  h_overall_std  \
# 10       3.05             8.24             8.45           2.23
# 11       3.69             7.20             7.65           2.40
# 12       4.22             8.74             8.96           2.27
# 13       2.16             6.32             7.44           2.76
# 14       4.07             7.10             7.14           3.15
#
#     h_potential_std  h_int_repn_std  h_skills_moves_std  a_total_value_eur  \
# 10             3.20            0.43                1.04          204200000
# 11             3.79            0.56                0.86          491900000
# 12             4.23            0.37                0.95          434500000
# 13             2.59            0.39                0.59          128550000
# 14             3.69            0.51                0.73          142700000
#
#     a_total_wage_eur  a_average_age  a_average_height_cm  a_average_weight_kg  \
# 10           1646000          27.16               183.89                77.37
# 11           2420000          25.76               184.71                76.29
# 12           2245000          26.28               181.11                75.56
# 13           1060000          27.67               185.06                79.06
# 14            870000          27.24               183.76                79.53
#
#     a_average_overall  a_average_potential  a_average_int_rep  \
# 10              77.11                79.89               2.11
# 11              82.29                84.88               2.71
# 12              81.11                83.94               2.72
# 13              75.50                77.67               1.78
# 14              76.65                78.94               1.65
#
#     a_average_skill_moves  a_age_std  a_height_cm_std  a_weight_kg_std  \
# 10                   2.53       3.69             8.20             7.65
# 11                   2.94       3.44             7.56             8.74
# 12                   2.78       3.92             6.59             7.33
# 13                   2.50       4.03             4.48             5.91
# 14                   2.65       3.77             5.54             9.62
#
#     a_overall_std  a_potential_std  a_int_rep_std  a_skills_moves_std
# 10           5.35             2.60           0.66                0.90
# 11           3.74             4.91           0.69                0.97
# 12           5.42             3.21           0.96                0.81
# 13           4.62             3.77           0.55                0.71
# 14           2.21             3.42           0.49                0.79

# %%
#Dropping of irrelevant features
train_1 = train.drop(columns = ['a_total_goals','result','attendance','h_gls','h_ast','h_pk','h_pkatt','h_sh','h_sot','h_yellow','h_red',
                              'h_touches','h_press','h_tkl','h_int','h_blk','h_xg','h_xa','h_sca','h_gca','h_cmp','h_pass_att',
                              'h_pass_prog','h_carries','h_carries_prog','h_dri_succ','h_dri_att','h_yellow2','h_fls','h_fld','h_off',
                              'h_crs','h_tklw','h_pkwon','h_pkcon','h_og','h_recov','h_aer_won','h_aer_lost','h_last5match','a_last5match','a_gls',
                              'a_ast','a_pk','a_pkatt','a_sh','a_sot','a_yellow', 'a_red', 'a_touches', 'a_press', 'a_tkl', 'a_int', 'a_blk',
                             'a_xg','a_xa','a_sca','a_gca','a_cmp','a_pass_att','a_pass_prog','a_carries', 'a_carries_prog', 'a_dri_succ',
                              'a_dri_att','a_yellow2','a_fls','a_fld','a_off','a_crs','a_tklw','a_pwon','a_pkcon','a_og','a_recov','a_aer_won','a_aer_lost',
                                'total_goals','h_npxg','a_npxg'])

# %%
plt.figure(figsize=(15,50))
sns.heatmap(train_1.corr()[['h_total_goals']].sort_values('h_total_goals'), annot=True,center =0)
plt.title('H_total_goals VS Features')
# Out:
# Text(0.5, 1.0, 'H_total_goals VS Features')

# %% [markdown]
# Looking at the heatmap, some home features are very negatively correlated. Features such as past matches blocks, home team average height. Other features includes away team value and away average overall.
#
# Positively correlated features are mostly home team stats, such as team total wages and values, team average potential and value. The only past matches feature is average carries for last 5 matches.
#
# We will remove features which are correlated between 0.24 to -0.15. This is due to that there are lesser features that are negatively correlated and we will try to make the features balanced

# %%
#Trying to find the balance
train_corrs = train_1.corrwith(train['h_total_goals'])
train_corrs_index = train_corrs[(train_corrs < 0.24) & (train_corrs > -0.15)].index
list(train_corrs_index)
# Out:
# ['h_last_5_avrg_gls',
#  'h_last_5_avrg_ast',
#  'h_last_5_avrg_pk',
#  'h_last_5_avrg_pkatt',
#  'h_last_5_avrg_yellow',
#  'h_last_5_avrg_red',
#  'h_last_5_avrg_press',
#  'h_last_5_avrg_tkl',
#  'h_last_5_avrg_int',
#  'h_last_5_avrg_gca',
#  'h_last_5_avrg_dri_succ',
#  'h_last_5_avrg_dri_att',
#  'h_last_5_avrg_yellow2',
#  'h_last_5_avrg_fld',
#  'h_last_5_avrg_off',
#  'h_last_5_avrg_crs',
#  'h_last_5_avrg_tklw',
#  'h_last_5_avrg_pkwon',
#  'h_last_5_avrg_pkcon',
#  'h_last_5_avrg_og',
#  'h_last_5_avrg_recov',
#  'h_last_5_avrg_aer_won',
#  'h_last_3_avrg_gls',
#  'h_last_3_avrg_ast',
#  'h_last_3_avrg_pk',
#  'h_last_3_avrg_pkatt',
#  'h_last_3_avrg_yellow',
#  'h_last_3_avrg_red',
#  'h_last_3_avrg_press',
#  'h_last_3_avrg_tkl',
#  'h_last_3_avrg_int',
#  'h_last_3_avrg_gca',
#  'h_last_3_avrg_dri_succ',
#  'h_last_3_avrg_dri_att',
#  'h_last_3_avrg_yellow2',
#  'h_last_3_avrg_fls',
#  'h_last_3_avrg_fld',
#  'h_last_3_avrg_off',
#  'h_last_3_avrg_crs',
#  'h_last_3_avrg_tklw',
#  'h_last_3_avrg_pkwon',
#  'h_last_3_avrg_pkcon',
#  'h_last_3_avrg_og',
#  'h_last_3_avrg_recov',
#  'h_last_3_avrg_aer_won',
#  'h_last_3_avrg_aer_lost',
#  'a_last_5_avrg_ast',
#  'a_last_5_avrg_pk',
#  'a_last_5_avrg_pkatt',
#  'a_last_5_avrg_sh',
#  'a_last_5_avrg_sot',
#  'a_last_5_avrg_yellow',
#  'a_last_5_avrg_red',
#  'a_last_5_touches',
#  'a_last_5_avrg_press',
#  'a_last_5_avrg_tkl',
#  'a_last_5_avrg_int',
#  'a_last_5_avrg_blk',
#  'a_last_5_avrg_xa',
#  'a_last_5_avrg_sca',
#  'a_last_5_avrg_cmp',
#  'a_last_5_avrg_pass_att',
#  'a_last_5_avrg_pass_prog',
#  'a_last_5_avrg_carries',
#  'a_last_5_avrg_carries_prog',
#  'a_last_5_avrg_dri_succ',
#  'a_last_5_avrg_dri_att',
#  'a_last_5_avrg_yellow2',
#  'a_last_5_avrg_fls',
#  'a_last_5_avrg_fld',
#  'a_last_5_avrg_off',
#  'a_last_5_avrg_crs',
#  'a_last_5_avrg_tklw',
#  'a_last_5_avrg_pkwon',
#  'a_last_5_avrg_pkcon',
#  'a_last_5_avrg_og',
#  'a_last_5_avrg_recov',
#  'a_last_5_avrg_aer_won',
#  'a_last_5_avrg_aer_lost',
#  'a_last_3_avrg_ast',
#  'a_last_3_avrg_pk',
#  'a_last_3_avrg_pkatt',
#  'a_last_3_avrg_sh',
#  'a_last_3_avrg_sot',
#  'a_last_3_avrg_yellow',
#  'a_last_3_avrg_red',
#  'a_last_3_touches',
#  'a_last_3_avrg_press',
#  'a_last_3_avrg_tkl',
#  'a_last_3_avrg_int',
#  'a_last_3_avrg_blk',
#  'a_last_3_avrg_xg',
#  'a_last_3_avrg_xa',
#  'a_last_3_avrg_sca',
#  'a_last_3_avrg_cmp',
#  'a_last_3_avrg_pass_att',
#  'a_last_3_avrg_pass_prog',
#  'a_last_3_avrg_carries',
#  'a_last_3_avrg_carries_prog',
#  'a_last_3_avrg_dri_succ',
#  'a_last_3_avrg_dri_att',
#  'a_last_3_avrg_yellow2',
#  'last_3_avrg_fls_y',
#  'a_last_3_avrg_fld',
#  'a_last_3_avrg_off',
#  'a_last_3_avrg_crs',
#  'a_last_3_avrg_tklw',
#  'a_last_3_avrg_pkwon',
#  'a_last_3_avrg_pkcon',
#  'a_last_3_avrg_og',
#  'a_last_3_avrg_recov',
#  'a_last_3_avrg_aer_won',
#  'a_last_3_avrg_aer_lost',
#  'h_accumulatpts',
#  'a_accumulatpts',
#  'h_average_age',
#  'h_age_std',
#  'h_height_cm_std',
#  'h_weight_kg_std',
#  'h_overall_std',
#  'h_potential_std',
#  'h_skills_moves_std',
#  'a_average_age',
#  'a_average_height_cm',
#  'a_average_weight_kg',
#  'a_average_int_rep',
#  'a_age_std',
#  'a_height_cm_std',
#  'a_weight_kg_std',
#  'a_overall_std',
#  'a_potential_std',
#  'a_int_rep_std',
#  'a_skills_moves_std']

# %%
#Dropping columns that are not so correlaed
train_h = train_1.drop(columns = train_corrs_index)

# %%
#Restudying the heatmap of the correlation between away total goals and remaining features
#Correlation between result and other features
plt.figure(figsize=(15,30))
sns.heatmap(train_h.corr()[['h_total_goals']].sort_values('h_total_goals'), annot=True,center =0)
plt.title('Home Total Goals VS Features')
# Out:
# Text(0.5, 1.0, 'Home Total Goals VS Features')

# %% [markdown]
# Most of the remaining features belong to the home team, and the most positive correlated ones are the team stats.

# %%
#Shape of the final data
train_h.shape
# Out:
# (1302, 51)

# %%
train_h.columns
# Out:
# Index(['date', 'match', 'home', 'stadium', 'h_last_5_avrg_sh',
#        'h_last_5_avrg_sot', 'h_last_5_touches', 'h_last_5_avrg_blk',
#        'h_last_5_avrg_xg', 'h_last_5_avrg_xa', 'h_last_5_avrg_sca',
#        'h_last_5_avrg_cmp', 'h_last_5_avrg_pass_att',
#        'h_last_5_avrg_pass_prog', 'h_last_5_avrg_carries',
#        'h_last_5_avrg_carries_prog', 'h_last_5_avrg_fls',
#        'h_last_5_avrg_aer_lost', 'h_last_3_avrg_sh', 'h_last_3_avrg_sot',
#        'h_last_3_touches', 'h_last_3_avrg_blk', 'h_last_3_avrg_xg',
#        'h_last_3_avrg_xa', 'h_last_3_avrg_sca', 'h_last_3_avrg_cmp',
#        'h_last_3_avrg_pass_att', 'h_last_3_avrg_pass_prog',
#        'h_last_3_avrg_carries', 'h_last_3_avrg_carries_prog', 'away',
#        'a_last_5_avrg_gls', 'a_last_5_avrg_xg', 'a_last_5_avrg_gca',
#        'a_last_3_avrg_gls', 'a_last_3_avrg_gca', 'h_total_goals',
#        'h_total_value_eur', 'h_total_wage_eur', 'h_average_height_cm',
#        'h_average_weight_kg', 'h_average_overall', 'h_average_potential',
#        'h_int_rep', 'h_skill_moves', 'h_int_repn_std', 'a_total_value_eur',
#        'a_total_wage_eur', 'a_average_overall', 'a_average_potential',
#        'a_average_skill_moves'],
#       dtype='object')

# %% [markdown]
# ## Building the Model
#
# ### Train Test Split for Home Total Goals
#
# We will be splitting the data into train and test set. After that, we will smote the train set as the dataset is very imbalanced.

# %%
train_h.head()
# Out:
#           date                              match          home  \
# 10  2017-08-19     Southampton_vs_West_Ham_United   Southampton
# 11  2017-08-19  Swansea_City_vs_Manchester_United  Swansea City
# 12  2017-08-19              Stoke_City_vs_Arsenal    Stoke City
# 13  2017-08-19    Burnley_vs_West_Bromwich_Albion       Burnley
# 14  2017-08-19             Bournemouth_vs_Watford   Bournemouth
#
#                                 stadium  h_last_5_avrg_sh  h_last_5_avrg_sot  \
# 10      St. Mary's Stadium, Southampton              30.0                3.0
# 11  Liberty Stadium, Swansea, Glamorgan               4.0                0.0
# 12       Bet365 Stadium, Stoke-on-Trent              10.0                1.0
# 13                   Turf Moor, Burnley              10.0                5.0
# 14        Vitality Stadium, Bournemouth               9.0                2.0
#
#     h_last_5_touches  h_last_5_avrg_blk  h_last_5_avrg_xg  h_last_5_avrg_xa  \
# 10             645.0               10.0               2.0               1.5
# 11             490.0               28.0               0.4               0.3
# 12             478.0               16.0               0.1               0.1
# 13             447.0               20.0               0.8               0.6
# 14             739.0               13.0               0.4               0.3
#
#     h_last_5_avrg_sca  h_last_5_avrg_cmp  h_last_5_avrg_pass_att  \
# 10               47.0              437.0                   549.0
# 11                7.0              292.0                   383.0
# 12               15.0              229.0                   361.0
# 13               16.0              248.0                   344.0
# 14               14.0              530.0                   642.0
#
#     h_last_5_avrg_pass_prog  h_last_5_avrg_carries  \
# 10                     41.0                  439.0
# 11                     21.0                  304.0
# 12                     33.0                  269.0
# 13                     23.0                  235.0
# 14                     41.0                  589.0
#
#     h_last_5_avrg_carries_prog  h_last_5_avrg_fls  h_last_5_avrg_aer_lost  \
# 10                        60.0               11.0                     8.0
# 11                        17.0               15.0                    11.0
# 12                        36.0               12.0                     9.0
# 13                        23.0               14.0                     8.0
# 14                        55.0                3.0                     9.0
#
#     h_last_3_avrg_sh  h_last_3_avrg_sot  h_last_3_touches  h_last_3_avrg_blk  \
# 10              30.0                3.0             645.0               10.0
# 11               4.0                0.0             490.0               28.0
# 12              10.0                1.0             478.0               16.0
# 13              10.0                5.0             447.0               20.0
# 14               9.0                2.0             739.0               13.0
#
#     h_last_3_avrg_xg  h_last_3_avrg_xa  h_last_3_avrg_sca  h_last_3_avrg_cmp  \
# 10               2.0               1.5               47.0              437.0
# 11               0.4               0.3                7.0              292.0
# 12               0.1               0.1               15.0              229.0
# 13               0.8               0.6               16.0              248.0
# 14               0.4               0.3               14.0              530.0
#
#     h_last_3_avrg_pass_att  h_last_3_avrg_pass_prog  h_last_3_avrg_carries  \
# 10                   549.0                     41.0                  439.0
# 11                   383.0                     21.0                  304.0
# 12                   361.0                     33.0                  269.0
# 13                   344.0                     23.0                  235.0
# 14                   642.0                     41.0                  589.0
#
#     h_last_3_avrg_carries_prog                  away  a_last_5_avrg_gls  \
# 10                        60.0       West Ham United                0.0
# 11                        17.0     Manchester United                4.0
# 12                        36.0               Arsenal                4.0
# 13                        23.0  West Bromwich Albion                1.0
# 14                        55.0               Watford                3.0
#
#     a_last_5_avrg_xg  a_last_5_avrg_gca  a_last_3_avrg_gls  a_last_3_avrg_gca  \
# 10               0.6                0.0                0.0                0.0
# 11               2.0                7.0                4.0                7.0
# 12               2.2                7.0                4.0                7.0
# 13               1.1                2.0                1.0                2.0
# 14               1.9                3.0                3.0                3.0
#
#     h_total_goals  h_total_value_eur  h_total_wage_eur  h_average_height_cm  \
# 10              3          192000000           1330000               182.28
# 11              0          129600000            970000               182.29
# 12              1          173000000           1010000               185.06
# 13              0          103475000            810000               182.65
# 14              0          115200000            970000               180.06
#
#     h_average_weight_kg  h_average_overall  h_average_potential  h_int_rep  \
# 10                76.78              77.17                80.44       1.78
# 11                78.59              75.53                78.41       1.76
# 12                80.44              77.31                80.19       2.00
# 13                77.12              74.29                76.06       1.18
# 14                75.44              74.56                78.33       1.17
#
#     h_skill_moves  h_int_repn_std  a_total_value_eur  a_total_wage_eur  \
# 10           2.61            0.43          204200000           1646000
# 11           2.88            0.56          491900000           2420000
# 12           2.69            0.37          434500000           2245000
# 13           2.29            0.39          128550000           1060000
# 14           2.78            0.51          142700000            870000
#
#     a_average_overall  a_average_potential  a_average_skill_moves
# 10              77.11                79.89                   2.53
# 11              82.29                84.88                   2.94
# 12              81.11                83.94                   2.78
# 13              75.50                77.67                   2.50
# 14              76.65                78.94                   2.65

# %%
train_h_2 = train_h.drop(columns = ['h_total_goals'])

# %%
X = train_h[train_h_2.columns]
y = train_h['h_total_goals']

# %%
X.shape
# Out:
# (1302, 50)

# %%
#We will split the data accordingly to order as it is date time sensitive
X_train_full, X_test_full, y_train, y_test = train_test_split(X, y, random_state=42,shuffle=False)

# %%
X_train = X_train_full.drop(columns = ['date','match','home','away','stadium'])
X_test = X_test_full.drop(columns = ['date','match','home','away','stadium'])

# %%
#As the ranges of the features are differnet, lets normalize
mm = MinMaxScaler()
Xmm_train = mm.fit_transform(X_train)
Xmm_test = mm.transform(X_test)

# %%
y_train.value_counts(normalize=True)
# Out:
# 1    0.332992
# 2    0.257172
# 0    0.222336
# 3    0.108607
# 4    0.050205
# 5    0.025615
# 6    0.003074
# Name: h_total_goals, dtype: float64

# %%
#Smote-ing to balance the data
sm = SMOTE(random_state=42,k_neighbors=1)

Xsm_train, ysm_train = sm.fit_sample(Xmm_train, y_train)

# %%
ysm_train.value_counts(normalize=True)
# Out:
# 0    0.142857
# 2    0.142857
# 4    0.142857
# 6    0.142857
# 1    0.142857
# 3    0.142857
# 5    0.142857
# Name: h_total_goals, dtype: float64

# %% [markdown]
# ### Logistic Regression
#
# In this section, we will use Logistic Regression.

# %%
#Gridsearch to look for best params
lr = LogisticRegression(random_state=42)
lr_params = {
    'C': np.linspace(0.1,1,5)
}
#Gridsearch and fit the model
gs_lr = GridSearchCV(lr, param_grid = lr_params, cv=5,n_jobs=-1, verbose=1,scoring='f1_micro')
gs_lr.fit(Xsm_train, ysm_train)

#Getting the best params
gs_lr.best_estimator_
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:    2.6s finished
# LogisticRegression(random_state=42)

# %%
lr = LogisticRegression(random_state=42)

# %%
lr.fit(Xsm_train, ysm_train)
# Out:
# LogisticRegression(random_state=42)

# %% [markdown]
# #### Evaluation of Logistic Regression Model

# %%
print(lr.score(Xsm_train, ysm_train))
print(lr.score(Xmm_test,y_test))
# Out:
# 0.5072527472527473
# 0.254601226993865

# %%
lr_coeff = np.exp(lr.coef_[0])
imp_lr = pd.DataFrame(lr_coeff, X_train.columns, columns=['coef']).sort_values(by='coef',ascending=False)
imp_lr.head(53)
# Out:
#                                 coef
# a_total_value_eur           5.336588
# a_last_3_avrg_gca           4.764687
# a_last_5_avrg_xg            2.431878
# h_average_weight_kg         2.051455
# h_average_height_cm         1.988452
# h_last_5_avrg_blk           1.975032
# a_last_3_avrg_gls           1.905481
# h_last_5_avrg_fls           1.747808
# h_last_3_avrg_sot           1.673863
# h_last_3_avrg_cmp           1.649264
# a_average_overall           1.576686
# h_last_5_avrg_sca           1.531442
# h_last_5_avrg_cmp           1.351898
# h_last_5_avrg_sh            1.336332
# h_last_3_avrg_carries       1.311765
# h_total_wage_eur            1.305235
# h_last_3_avrg_xg            1.270328
# h_last_3_avrg_sca           1.086006
# h_last_5_avrg_aer_lost      1.069940
# a_last_5_avrg_gca           1.063496
# h_last_5_avrg_carries       1.030202
# h_last_3_touches            1.027902
# h_skill_moves               0.977604
# a_average_skill_moves       0.954246
# h_last_3_avrg_pass_att      0.899613
# h_last_5_avrg_xg            0.897987
# a_last_5_avrg_gls           0.836071
# h_last_5_avrg_pass_att      0.824609
# h_average_overall           0.801558
# h_last_5_avrg_xa            0.801011
# h_last_3_avrg_xa            0.788735
# h_last_5_touches            0.732388
# h_last_3_avrg_sh            0.730116
# h_int_rep                   0.702312
# h_average_potential         0.610956
# h_last_5_avrg_carries_prog  0.597824
# a_total_wage_eur            0.578240
# h_last_5_avrg_sot           0.575800
# a_average_potential         0.551666
# h_last_5_avrg_pass_prog     0.501333
# h_last_3_avrg_carries_prog  0.473144
# h_last_3_avrg_pass_prog     0.404923
# h_total_value_eur           0.387618
# h_last_3_avrg_blk           0.289587
# h_int_repn_std              0.270818

# %%
# Plotting top 20 +ve features in bar chart
imp_lr.head(20).plot(kind='barh', figsize=(10,6))
plt.title('Top 20 Feature Coefficients (+ve) for Logistic Regression', fontsize=15)
plt.gca().invert_yaxis()
plt.legend(loc=4);

imp_lr.tail(20).plot(kind='barh', figsize=(10,6))
plt.title('Top 20 Feature Coefficients (-ve) for Logistic Regression', fontsize=15)
plt.gca().invert_yaxis()
plt.legend(loc=4);

# %% [markdown]
# There is a large overfitting of the data based on the train and test score.
#
# For the top 20 positive feature coefficients, there are a mixture of past matches and team statistics. Similar, the top 20 negative feature coefficients have a mixture of past matches and team statistics. However, mostly are home related stats. It is a bit of different as better performance of the home team should have a higher chance of scoring a goal.

# %%
# Initialize empty list to store all the scores and corresponding model names
model_name = []
model_scores = []
model_var = []
model_test_scores = []

#Adding into list for evaluation
model_name.append('Logistic Regression')
model_scores.append(lr.score(Xsm_train, ysm_train))
model_var.append(lr)
model_test_scores.append(lr.score(Xmm_test,y_test))

# %% [markdown]
# ### Random Forest Classification
#
# Here we will be using the Random Forest Classification.

# %%
rf = RandomForestClassifier(random_state=42)
#Include params to test
rf_params = {
    'n_estimators': [80, 100, 120],
    'max_depth': [3, 5],
    'min_samples_leaf': [2, 4],
    'min_samples_split' : [2, 4]
}
#Grid-Searching
gs_rf = GridSearchCV(rf, param_grid = rf_params, cv=5,n_jobs=-1,verbose=1,scoring='f1_micro')
#Fitting the model and getting the best estimator
gs_rf.fit(Xsm_train, ysm_train)
gs_rf.best_estimator_
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    4.0s finished
# RandomForestClassifier(max_depth=5, min_samples_leaf=2, n_estimators=120,
#                        random_state=42)

# %%
rf = RandomForestClassifier(max_depth=5, min_samples_leaf=2, n_estimators=120,
                       random_state=42)

# %%
rf.fit(Xsm_train, ysm_train)
# Out:
# RandomForestClassifier(max_depth=5, min_samples_leaf=2, n_estimators=120,
#                        random_state=42)

# %% [markdown]
# #### Evaluation of Random Forest Model

# %%
print(rf.score(Xsm_train, ysm_train))
print(rf.score(Xmm_test,y_test))
# Out:
# 0.6395604395604395
# 0.2791411042944785

# %%
#Random Forest Features ranked by importanc
rf_impt_feature = rf.feature_importances_
rf_impt_df = pd.DataFrame(index = X_test.columns, data = rf_impt_feature, columns = ['Importance']).sort_values('Importance',ascending=False)
rf_impt_df.head()
# Out:
#                      Importance
# h_average_weight_kg    0.091019
# h_average_height_cm    0.066033
# h_average_potential    0.065338
# h_total_value_eur      0.054026
# h_average_overall      0.052873

# %%
rf_impt_df.head(20).plot(kind='barh',figsize=(12,7),color='red',label=rf_impt_df.columns[:20])
plt.title('Top 20 Feature Importance for Random Forest')
plt.gca().invert_yaxis()
plt.legend(loc=4);

# %% [markdown]
# The top 5 important features for Random Forest are the home total value, average potential, total wage, average height and international reputation. It seems that team statistics are more important in this model. I think the decision outcomes get influenced by how good or how strong the home team is.
#
# The training score and test score are very wide apart. There is alot of overfitting in the data.

# %%
# DOT data
dotfile = open("images/tree_home_goals.dot", 'w')
dot_data = export_graphviz(rf.estimators_[10], out_file=None, 
                               feature_names= X_train.columns,  
                               class_names=['0','1','2','3','4','5','6'],
                                filled=True)

#Draw graph
graph = graphviz.Source(dot_data, format="png") 
graph

# %% [markdown]
# Despite the importance being mostly team stats, the random forest trees use a lot of past matches stats.

# %%
#Adding into list for evaluation
model_name.append('Random Forest')
model_scores.append(rf.score(Xsm_train, ysm_train))
model_var.append(rf)
model_test_scores.append(rf.score(Xmm_test,y_test))

# %% [markdown]
# ### ExtraTrees Classifier
#
# Here we will be exploring the usage of ExtraTrees Classifier.

# %%
et = ExtraTreesClassifier(random_state=42)
# Including hyperparameters
et_params = {
    'n_estimators': [80, 100, 120],
    'max_depth': [3, 5],
    'min_samples_leaf': [2, 4],
    'min_samples_split' : [2, 4],
}
#Grid-Searching
gs_et = GridSearchCV(et, param_grid = et_params, cv=5,n_jobs=-1,verbose=1,scoring='f1_micro')
gs_et.fit(Xsm_train, ysm_train)
#Getting the best estimator
gs_et.best_estimator_
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    1.9s finished
# ExtraTreesClassifier(max_depth=5, min_samples_leaf=2, n_estimators=120,
#                      random_state=42)

# %%
#Using the best parameters and fit the model
et = ExtraTreesClassifier(max_depth=5, min_samples_leaf=2,n_estimators=120,random_state=42)
et.fit(Xsm_train, ysm_train)
# Out:
# ExtraTreesClassifier(max_depth=5, min_samples_leaf=2, n_estimators=120,
#                      random_state=42)

# %% [markdown]
# #### Evaluation of ExtraTrees Classifier

# %%
print(et.score(Xsm_train,ysm_train))
print(et.score(Xmm_test,y_test))
# Out:
# 0.5995604395604396
# 0.24539877300613497

# %%
et_impt_feature = et.feature_importances_
et_impt_df = pd.DataFrame(index = X_test.columns, data = et_impt_feature, columns = ['Importance']).sort_values('Importance',ascending=False)
et_impt_df.head()
# Out:
#                      Importance
# h_total_value_eur      0.084277
# h_average_weight_kg    0.056153
# h_average_potential    0.056085
# h_average_height_cm    0.055608
# h_total_wage_eur       0.049154

# %%
# Top 20 features plot
et_impt_df.head(20).plot(kind='barh', label=et_impt_df.columns, figsize=(12,7), color='orange')
plt.title('Top 20 Feature Importance for Extra Trees', fontsize=15)
plt.gca().invert_yaxis()
plt.legend(loc=4);

# %% [markdown]
# There is an overfit. The train and test score are quite wide apart.
#
# The top 20 important features for Extra Tree model are similar to Random Forest model. Mostly are team statistics except for home last 5 average carries progressive being the only past match stats.
#
# Most of the top 20 feature importances for extra tree are related to the home team. I assume that it is influenced by how strong the home team is.

# %%
#Adding into list for evaluation
model_name.append('Extra Trees')
model_scores.append(et.score(Xsm_train, ysm_train))
model_var.append(et)
model_test_scores.append(et.score(Xmm_test,y_test))

# %% [markdown]
# ### AdaBoost Classifier
#
# In this section, we will explore the usage of AdaBoost Classifier.

# %%
# ada =  AdaBoostClassifier(random_state=42)

# Hyperparameters
ada_params = {
    'n_estimators': [20, 30, 40, 50],
    'learning_rate': [0.8, 0.9, 1]
}

gs_ada = GridSearchCV(ada, param_grid = ada_params, cv=5, n_jobs=-1,verbose=1,scoring='f1_micro')
gs_ada.fit(Xsm_train, ysm_train)
gs_ada.best_estimator_
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:    4.1s finished
# AdaBoostClassifier(learning_rate=0.9, n_estimators=30, random_state=42)

# %%
ada = AdaBoostClassifier(learning_rate=0.9, n_estimators=30, random_state=42)
ada.fit(Xsm_train, ysm_train)
# Out:
# AdaBoostClassifier(learning_rate=0.9, n_estimators=30, random_state=42)

# %% [markdown]
# #### Evaluation of AdaBoost Classifier

# %%
print(ada.score(Xsm_train, ysm_train))
print(ada.score(Xmm_test,y_test))
# Out:
# 0.46505494505494505
# 0.3006134969325153

# %%
#Ada Feature Importance
ada_impt_feature = ada.feature_importances_
ada_impt_df = pd.DataFrame(index = X_test.columns, data = ada_impt_feature, columns = ['Importance']).sort_values('Importance',ascending=False)
ada_impt_df.head()
# Out:
#                         Importance
# h_average_potential       0.300000
# h_average_weight_kg       0.233333
# h_last_5_avrg_aer_lost    0.033333
# a_last_5_avrg_gca         0.033333
# a_last_3_avrg_gca         0.033333

# %%
ada_impt_df.head(20).plot(kind='barh', label=ada_impt_df.columns[:20], figsize=(12,7), color='cyan')
plt.title('Top 20 Feature Importance for AdaBoost', fontsize=15)
plt.gca().invert_yaxis()

# %% [markdown]
# The train and test score are closer compared to the other models above.
#
# There are a mixture of past matches stats and team stats for the top important features. However, the most important is home average potential which is a team stat. So far, most of the models are very influenced by the home team average potential.

# %%
#Adding into list for evaluation
model_name.append('AdaBoost')
model_scores.append(ada.score(Xsm_train, ysm_train))
model_var.append(ada)
model_test_scores.append(ada.score(Xmm_test,y_test))

# %% [markdown]
# ### Gradient Boost Classifier
#
# We will explore the usage of Gradient Boost Classifier in this section.

# %%
gboost = GradientBoostingClassifier(random_state=42)
#Setting the params
gboost_params = {
    'n_estimators': [80, 100, 120, 150],
    'max_depth': [1, 2, 3],
    'min_samples_split': [2, 4],
    'min_samples_leaf': [1, 2]}
    
#Grid searching    
gs_gboost = GridSearchCV(gboost, param_grid = gboost_params, cv=5,n_jobs=-1,verbose=1,scoring='f1_micro')
#Fit the model
gs_gboost.fit(Xsm_train, ysm_train)
#Getting the best params
gs_gboost.best_estimator_
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:   13.6s
# [Parallel(n_jobs=-1)]: Done 176 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 240 out of 240 | elapsed:  3.4min finished
# GradientBoostingClassifier(n_estimators=150, random_state=42)

# %%
gboost = GradientBoostingClassifier(n_estimators=150,random_state=42)
gboost.fit(Xsm_train, ysm_train)
# Out:
# GradientBoostingClassifier(n_estimators=150, random_state=42)

# %% [markdown]
# #### Evaluation of Gradient Boost Classifier

# %%
print(gboost.score(Xsm_train,ysm_train))
print(gboost.score(Xmm_test,y_test))
# Out:
# 0.9876923076923076
# 0.3128834355828221

# %%
imp_gboost = pd.DataFrame(gboost.feature_importances_,index=X_test.columns,columns=['importance']).sort_values(by='importance', ascending=False)
imp_gboost.head()
# Out:
#                          importance
# h_average_potential        0.126613
# h_average_weight_kg        0.083454
# h_last_3_avrg_pass_prog    0.047235
# h_last_5_avrg_blk          0.032721
# h_skill_moves              0.029828

# %%
# Plot in bar chart
imp_gboost.head(20).plot(kind='barh', label=imp_gboost.columns[:20], figsize=(12,7), color='green')
plt.title('Top 20 Feature Importance for Gradient Boost', fontsize=15)
plt.gca().invert_yaxis()
plt.legend(loc=4);

# %% [markdown]
# Based on the scoring, there is a large overfit. The train score is almost 1, but the test score is slightly lower than baseline score.
#
# Similar, the top most important feature here is home team average potential. This model has more past match performances which is more important.

# %%
#Adding into list for evaluation
model_name.append('GradientBoosting')
model_scores.append(gboost.score(Xsm_train, ysm_train))
model_var.append(gboost)
model_test_scores.append(gboost.score(Xmm_test, y_test))

# %% [markdown]
# ### Support Vector Classifier
#
# In this section, we will try to build our model using support vector classifier.

# %%
svc = SVC(random_state=42)

# Setting Params
svc_params = {
    'C': [1, 0.1],
    'kernel': ['rbf', 'poly'],
    'degree': [2, 3]
}

gs_svc = GridSearchCV(svc, param_grid = svc_params, cv=5,n_jobs=-1, verbose=1,scoring='f1_micro')

gs_svc.fit(Xsm_train, ysm_train)
#Getting the best params
gs_svc.best_estimator_
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  40 out of  40 | elapsed:    0.8s finished
# SVC(C=1, kernel='poly', random_state=42)

# %%
svc = SVC(C=1, kernel='poly', random_state=42)
svc.fit(Xsm_train, ysm_train)
# Out:
# SVC(C=1, kernel='poly', random_state=42)

# %%
#There is an overfit on the data
print(svc.score(Xmm_train,y_train))
print(svc.score(Xmm_test,y_test))
# Out:
# 0.625
# 0.2852760736196319

# %% [markdown]
# There is still an overfit. The baseline score is higher than the test score.

# %%
#Adding into list for evaluation
model_name.append('Support Vector Classifier')
model_scores.append(svc.score(Xsm_train, ysm_train))
model_var.append(svc)
model_test_scores.append(svc.score(Xmm_test,y_test))

# %% [markdown]
# ### Model Evaluation & Selection
#
# In this section, we will put all the models together to evaluate and select the final model to use.

# %%
model_var
# Out:
# [LogisticRegression(random_state=42),
#  RandomForestClassifier(max_depth=5, min_samples_leaf=2, n_estimators=120,
#                         random_state=42),
#  ExtraTreesClassifier(max_depth=5, min_samples_leaf=2, n_estimators=120,
#                       random_state=42),
#  AdaBoostClassifier(learning_rate=0.9, n_estimators=30, random_state=42),
#  GradientBoostingClassifier(n_estimators=150, random_state=42),
#  SVC(C=1, kernel='poly', random_state=42)]

# %%
# View the evaluation metrics for all models in a dataframe
# Sorted by highest F1-Score
precision_list = []
recall_list = []
fscore_list = []

for model in model_var:
    y_pred = model.predict(Xmm_test)
    precision, recall, fscore, support = precision_recall_fscore_support(y_test, y_pred,average = 'micro')
    precision_list.append(precision)
    recall_list.append(recall)
    fscore_list.append(fscore)

# %%
pd.DataFrame({'Model Type': model_name,
              'F1-Score': fscore_list,
             'Recall': recall_list,
              'Precision': precision_list,
              'Train Accuracy': model_scores,
             'Test Accuracy': model_test_scores}).sort_values(by='F1-Score',ascending=False)
# Out:
#                   Model Type  F1-Score    Recall  Precision  Train Accuracy  \
# 4           GradientBoosting  0.312883  0.312883   0.312883        0.987692
# 3                   AdaBoost  0.300613  0.300613   0.300613        0.465055
# 5  Support Vector Classifier  0.285276  0.285276   0.285276        0.802637
# 1              Random Forest  0.279141  0.279141   0.279141        0.639560
# 0        Logistic Regression  0.254601  0.254601   0.254601        0.507253
# 2                Extra Trees  0.245399  0.245399   0.245399        0.599560
#
#    Test Accuracy
# 4       0.312883
# 3       0.300613
# 5       0.285276
# 1       0.279141
# 0       0.254601
# 2       0.245399

# %%
#Plotting of confusion Matrix
def subplot_confusion_matrix(model_list, model_name, Xmm_test, y_test):
    nrows = int(np.ceil(len(model_list)/3))   # Ensure have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=3, figsize=(14, nrows*4))   
    plt.subplots_adjust(hspace = 0.4)
    ax = ax.ravel()   # Ravel turns a matrix into a vector, which is easier to iterate
    for i, model in enumerate(model_list):   # Gives us an index value to get into all our lists
        plot_confusion_matrix(model, Xmm_test, y_test, cmap='Blues', values_format='d', ax=ax[i])
        ax[i].set_title(model_name[i])
    
        # display scale and label only on the left edge
        if i%3 != 0:
            ax[i].set_ylabel('')
            ax[i].set_yticklabels('')
    # This code below is to switch off the axes if there is an odd number of subplots
    for axes in ax.flat[len(model_list):]:
        axes.axis('off')
    fig.tight_layout()
    pass

# %%
subplot_confusion_matrix(model_var, model_name, Xmm_test, y_test)

# %% [markdown]
# We will be using F1 Score micro-average as the metric in this machine learning model.It is because that we have many seven different classes and imbalance classes in our data. So based on our model building outcome, the model with the best score is Gradient Boosting.
#
# Based on its top important features, it uses a mixture of team stats and match stats to train the model. We will be selecting Gradient boost for our production model for Home Total Goals.
#
# [Gradient boosting](https://corporatefinanceinstitute.com/resources/knowledge/other/boosting/), just like any other ensemble machine learning procedure, sequentially adds predictors to the ensemble and follows the sequence in correcting preceding predictors to arrive at an accurate predictor at the end of the procedure.
#
# It utilizes the gradient descent to pinpoint the challenges in the learners’ predictions used previously. The previous error is highlighted, and, by combining one weak learner to the next learner, the error is reduced significantly over time.
#
# Advantages:
#
# - Often provides predictive accuracy that cannot be beat.
# - Lots of flexibility - can optimize on different loss functions and provides several hyperparameter tuning options that make the function fit very flexible.
# - No data pre-processing required - often works great with categorical and numerical values as is.
# - Handles missing data - imputation not required.
#
# Disdvantages:
#
# - GBMs will continue improving to minimize all errors. This can overemphasize outliers and cause overfitting. Must use cross-validation to neutralize.
# - Computationally expensive - GBMs often require many trees (>1000) which can be time and memory exhaustive.
# - The high flexibility results in many parameters that interact and influence heavily the behavior of the approach (number of iterations, tree depth, regularization parameters, etc.). This requires a large grid search during tuning.
# - Less interpretable although this is easily addressed with various tools (variable importance, partial dependence plots, LIME, etc.).

# %%
#Saving scaler as pickle
filename = 'pkl/home_goals_scaler.pkl'
pickle.dump(mm, open(filename, 'wb'))

# %%
#Saving model as pickle
filename = 'pkl/home_goals_production_model.pkl'
pickle.dump(gboost, open(filename, 'wb'))
